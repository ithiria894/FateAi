# %%
import gc
import numpy as np
import os
import re
import sys

import pandas as pd
import tensorflow_data_validation as tfdv

#VERSION = "20221025"
DATA_DIR = r"Z:\13.Data Science\Projects\2022_GI_Xsell\Data"
PROJECT_DIR = "../"
RAW_DATA_DIR = os.path.join(DATA_DIR, "raw")
PROCESSED_DATA_DIR = os.path.join(DATA_DIR, "processed")
META_DATA_DIR = os.path.join(DATA_DIR, "meta_and_reference_data")
VER_1025_DIR = os.path.join(RAW_DATA_DIR, "20221025")
VER_1118_DIR = os.path.join(RAW_DATA_DIR, "20221118")
VER_1122_DIR = os.path.join(RAW_DATA_DIR, "20221122")
VER_1212_DIR = os.path.join(RAW_DATA_DIR, "20221212")
GI_DATA_DIR = os.path.join(RAW_DATA_DIR, "GI")
PA_DATA_DIR = os.path.join(GI_DATA_DIR, "Travel", "202210")
sys.path.insert(0, DATA_DIR)
sys.path.insert(0, PROJECT_DIR)

from datetime import datetime
from dateutil.relativedelta import relativedelta

from src.utils.common import PLAN_TYPE_LST, WGP_LST, INFORCE_STATUS_LST
from src.utils.helper_function import find_plan_type, one_hot

# %%
pd.set_option('display.width', None)
pd.set_option('max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
import os
# os.environ['KMP_DUPLICATE_LIB_OK']="TRUE"
prem_w_medical_df=pd.read_parquet(r"Z:\13.Data Science\Projects\2022_GI_Xsell\Code\notebooks\prem_w_medical_df.parquet")

# %%
prem_w_medical_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NICOLE~1.LEU\AppData\Local\Temp/ipykernel_22712/3961606304.py in <module>
# ----> 1 prem_w_medical_df.head()
#
# NameError: name 'prem_w_medical_df' is not defined

# %%
pip --disable-pip-version-check list --outdated --format=json | python -c "import json, sys; print('\n'.join([x['name'] for x in json.load(sys.stdin)]))"
# Out:
# alabaster
# anyio
# apache-beam
# argh
# argon2-cffi
# arrow
# asn1crypto
# astroid
# astropy
# atomicwrites
# attrs
# autopep8
# Babel
# bcrypt
# beautifulsoup4
# bitarray
# black
# bleach
# bokeh
# Bottleneck
# cachetools
# certifi
# cffi
# chardet
# charset-normalizer
# click
# colorama
# comtypes
# contextlib2
# cookiecutter
# cryptography
# cycler
# Cython
# cytoolz
# daal4py
# dask
# debugpy
# decorator
# dill
# distributed
# docutils
# entrypoints
# filelock
# flake8
# Flask
# fonttools
# fsspec
# future
# gast
# gevent
# google-api-python-client
# google-apitools
# google-auth
# google-auth-oauthlib
# google-cloud-bigquery-storage
# google-cloud-bigtable
# google-cloud-datastore
# google-cloud-language
# google-cloud-pubsublite
# google-cloud-recommendations-ai
# google-cloud-videointelligence
# greenlet
# grpcio-status
# h5py
# httplib2
# idna
# imagecodecs
# imageio
# imagesize
# importlib-metadata
# iniconfig
# ipykernel
# ipython
# ipywidgets
# isort
# itsdangerous
# jedi
# Jinja2
# json5
# jsonschema
# jupyter-client
# jupyter-console
# jupyter-core
# jupyter-server
# jupyterlab
# jupyterlab-pygments
# jupyterlab-server
# jupyterlab-widgets
# keyring
# kiwisolver
# lazy-object-proxy
# libarchive-c
# llvmlite
# locket
# lxml
# MarkupSafe
# matplotlib
# matplotlib-inline
# mccabe
# mistune
# mock
# more-itertools
# msgpack
# mypy-extensions
# nbclassic
# nbclient
# nbconvert
# nbformat
# nest-asyncio
# networkx
# nltk
# notebook
# numba
# numexpr
# numpy
# numpydoc
# openpyxl
# overrides
# packaging
# pandas
# pandocfilters
# paramiko
# parso
# partd
# path
# pathlib2
# pathspec
# patsy
# Pillow
# pip
# pkginfo
# pluggy
# prometheus-client
# prompt-toolkit
# protobuf
# psutil
# py
# pyarrow
# pycodestyle
# pycparser
# pycurl
# pydocstyle
# pyerfa
# pyflakes
# Pygments
# PyJWT
# pylint
# pymongo
# PyNaCl
# pyodbc
# pyOpenSSL
# pyparsing
# pyrsistent
# pytest
# python-lsp-black
# python-lsp-server
# python-slugify
# pytz
# PyWavelets
# pywin32
# pywinpty
# pyzmq
# QDarkStyle
# qstylizer
# QtAwesome
# qtconsole
# QtPy
# regex
# requests
# rope
# Rtree
# scikit-image
# scikit-learn
# scikit-learn-intelex
# scipy
# seaborn
# setuptools
# singledispatch
# sip
# sniffio
# snowballstemmer
# soupsieve
# Sphinx
# sphinxcontrib-applehelp
# sphinxcontrib-htmlhelp
# spyder
# spyder-kernels
# SQLAlchemy
# statsmodels
# sympy
# tables
# TBB
# tensorboard
# tensorboard-data-server
# terminado
# testpath
# textdistance
# threadpoolctl
# tifffile
# toolz
# tornado
# tqdm
# traitlets
# typed-ast
# typing-extensions
# ujson
# Unidecode
# uritemplate
# urllib3
# watchdog
# wcwidth
# Werkzeug
# wheel
# widgetsnbextension
# wrapt
# XlsxWriter
# xlwings
# xmltodict
# yapf
# zict
# zipp
# zope.event
# zope.interface
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list --outdated
# Out:
# Package                         Version              Latest      Type
# ------------------------------- -------------------- ----------- -----
# alabaster                       0.7.12               0.7.13      wheel
# anyio                           2.2.0                3.6.2       wheel
# apache-beam                     2.44.0               2.45.0      wheel
# argh                            0.26.2               0.28.1      wheel
# argon2-cffi                     20.1.0               21.3.0      wheel
# arrow                           0.13.1               1.2.3       wheel
# asn1crypto                      1.4.0                1.5.1       wheel
# astroid                         2.6.6                2.14.2      wheel
# astropy                         4.3.1                5.2.1       wheelNote: you may need to restart the kernel to use updated packages.
# atomicwrites                    1.4.0                1.4.1       sdist
# attrs                           21.2.0               22.2.0      wheel
# autopep8                        1.5.7                2.0.1       wheel
# Babel                           2.9.1                2.11.0      wheel
# bcrypt                          3.2.0                4.0.1       wheel
# beautifulsoup4                  4.10.0               4.11.2      wheel
# bitarray                        2.3.0                2.7.2       wheel
# black                           19.10b0              23.1.0      wheel
# bleach                          4.0.0                6.0.0       wheel
# bokeh                           2.4.1                3.0.3       wheel
# Bottleneck                      1.3.2                1.3.6       wheel
# cachetools                      4.2.4                5.3.0       wheel
# certifi                         2021.10.8            2022.12.7   wheel
# cffi                            1.14.6               1.15.1      wheel
# chardet                         4.0.0                5.1.0       wheel
# charset-normalizer              2.0.4                3.0.1       wheel
# click                           8.0.3                8.1.3       wheel
# colorama                        0.4.4                0.4.6       wheel
# comtypes                        1.1.10               1.1.14      wheel
# contextlib2                     0.6.0.post1          21.6.0      wheel
# cookiecutter                    1.7.2                2.1.1       wheel
# cryptography                    3.4.8                39.0.1      wheel
# cycler                          0.10.0               0.11.0      wheel
# Cython                          0.29.24              0.29.33     wheel
# cytoolz                         0.11.0               0.12.1      wheel
# daal4py                         2021.3.0             2023.0.1    wheel
# dask                            2021.10.0            2023.2.0    wheel
# debugpy                         1.4.1                1.6.6       wheel
# decorator                       5.1.0                5.1.1       wheel
# dill                            0.3.1.1              0.3.6       wheel
# distributed                     2021.10.0            2023.2.0    wheel
# docutils                        0.17.1               0.19        wheel
# entrypoints                     0.3                  0.4         wheel
# filelock                        3.3.1                3.9.0       wheel
# flake8                          3.9.2                6.0.0       wheel
# Flask                           1.1.2                2.2.3       wheel
#
# fonttools                       4.25.0               4.38.0      wheel
# fsspec                          2021.10.1            2023.1.0    wheel
# future                          0.18.2               0.18.3      sdist
# gast                            0.4.0                0.5.3       wheel
# gevent                          21.8.0               22.10.2     wheel
# google-api-python-client        1.12.11              2.78.0      wheel
# google-apitools                 0.5.31               0.5.32      wheel
# google-auth                     2.16.0               2.16.1      wheel
# google-auth-oauthlib            0.4.6                1.0.0       wheel
# google-cloud-bigquery-storage   2.13.2               2.18.1      wheel
# google-cloud-bigtable           1.7.3                2.15.0      wheel
# google-cloud-datastore          1.15.5               2.13.2      wheel
# google-cloud-language           1.3.2                2.9.0       wheel
# google-cloud-pubsublite         1.6.0                1.7.0       wheel
# google-cloud-recommendations-ai 0.7.1                0.10.1      wheel
# google-cloud-videointelligence  1.16.3               2.10.1      wheel
# greenlet                        1.1.1                2.0.2       wheel
# grpcio-status                   1.48.2               1.51.1      wheel
# h5py                            3.2.1                3.8.0       wheel
# httplib2                        0.20.4               0.21.0      wheel
# idna                            3.2                  3.4         wheel
# imagecodecs                     2021.8.26            2023.1.23   wheel
# imageio                         2.9.0                2.25.1      wheel
# imagesize                       1.2.0                1.4.1       wheel
# importlib-metadata              4.8.1                6.0.0       wheel
# iniconfig                       1.1.1                2.0.0       wheel
# ipykernel                       6.4.1                6.21.2      wheel
# ipython                         7.29.0               8.10.0      wheel
# ipywidgets                      7.6.5                8.0.4       wheel
# isort                           5.9.3                5.12.0      wheel
# itsdangerous                    2.0.1                2.1.2       wheel
# jedi                            0.18.0               0.18.2      wheel
# Jinja2                          2.11.3               3.1.2       wheel
# json5                           0.9.6                0.9.11      wheel
# jsonschema                      3.2.0                4.17.3      wheel
# jupyter-client                  6.1.12               8.0.3       wheel
# jupyter-console                 6.4.0                6.5.1       wheel
# jupyter-core                    4.8.1                5.2.0       wheel
# jupyter-server                  1.4.1                2.3.0       wheel
# jupyterlab                      3.2.1                3.6.1       wheel
# jupyterlab-pygments             0.1.2                0.2.2       wheel
# jupyterlab-server               2.8.2                2.19.0      wheel
# jupyterlab-widgets              1.0.0                3.0.5       wheel
# keyring                         23.1.0               23.13.1     wheel
# kiwisolver                      1.3.1                1.4.4       wheel
# lazy-object-proxy               1.6.0                1.9.0       wheel
# libarchive-c                    2.9                  4.0         wheel
# llvmlite                        0.37.0               0.39.1      wheel
# locket                          0.2.1                1.0.0       wheel
# lxml                            4.6.3                4.9.2       wheel
# MarkupSafe                      1.1.1                2.1.2       wheel
# matplotlib                      3.4.3                3.7.0       wheel
# matplotlib-inline               0.1.2                0.1.6       wheel
# mccabe                          0.6.1                0.7.0       wheel
# mistune                         0.8.4                2.0.5       wheel
# mock                            4.0.3                5.0.1       wheel
# more-itertools                  8.10.0               9.0.0       wheel
# msgpack                         1.0.2                1.0.4       wheel
# mypy-extensions                 0.4.3                1.0.0       wheel
# nbclassic                       0.2.6                0.5.2       wheel
# nbclient                        0.5.3                0.7.2       wheel
# nbconvert                       6.1.0                7.2.9       wheel
# nbformat                        5.1.3                5.7.3       wheel
# nest-asyncio                    1.5.1                1.5.6       wheel
# networkx                        2.6.3                3.0         wheel
# nltk                            3.6.5                3.8.1       wheel
# notebook                        6.1.5                6.5.2       wheel
# numba                           0.54.1               0.56.4      wheel
# numexpr                         2.7.3                2.8.4       wheel
# numpy                           1.20.3               1.24.2      wheel
# numpydoc                        1.1.0                1.5.0       wheel
# openpyxl                        3.0.9                3.1.1       wheel
# overrides                       6.5.0                7.3.1       wheel
# packaging                       21.0                 23.0        wheel
# pandas                          1.3.4                1.5.3       wheel
# pandocfilters                   1.4.3                1.5.0       wheel
# paramiko                        2.7.2                3.0.0       wheel
# parso                           0.8.2                0.8.3       wheel
# partd                           1.2.0                1.3.0       wheel
# path                            16.0.0               16.6.0      wheel
# pathlib2                        2.3.6                2.3.7.post1 wheel
# pathspec                        0.7.0                0.11.0      wheel
# patsy                           0.5.2                0.5.3       wheel
# Pillow                          8.4.0                9.4.0       wheel
# pip                             21.2.4               23.0.1      wheel
# pkginfo                         1.7.1                1.9.6       wheel
# pluggy                          0.13.1               1.0.0       wheel
# prometheus-client               0.11.0               0.16.0      wheel
# prompt-toolkit                  3.0.20               3.0.36      wheel
# protobuf                        3.19.6               4.22.0      wheel
# psutil                          5.8.0                5.9.4       wheel
# py                              1.10.0               1.11.0      wheel
# pyarrow                         6.0.1                11.0.0      wheel
# pycodestyle                     2.7.0                2.10.0      wheel
# pycparser                       2.20                 2.21        wheel
# pycurl                          7.44.1               7.45.2      sdist
# pydocstyle                      6.1.1                6.3.0       wheel
# pyerfa                          2.0.0                2.0.0.1     wheel
# pyflakes                        2.3.1                3.0.1       wheel
# Pygments                        2.10.0               2.14.0      wheel
# PyJWT                           2.1.0                2.6.0       wheel
# pylint                          2.9.6                2.16.2      wheel
# pymongo                         3.13.0               4.3.3       wheel
# PyNaCl                          1.4.0                1.5.0       wheel
# pyodbc                          4.0.0-unsupported    4.0.35      wheel
# pyOpenSSL                       21.0.0               23.0.0      wheel
# pyparsing                       3.0.4                3.0.9       wheel
# pyrsistent                      0.18.0               0.19.3      wheel
# pytest                          6.2.4                7.2.1       wheel
# python-lsp-black                1.0.0                1.2.1       wheel
# python-lsp-server               1.2.4                1.7.1       wheel
# python-slugify                  5.0.2                8.0.0       wheel
# pytz                            2021.3               2022.7.1    wheel
# PyWavelets                      1.1.1                1.4.1       wheel
# pywin32                         228                  305         wheel
# pywinpty                        0.5.7                2.0.10      wheel
# pyzmq                           22.2.1               25.0.0      wheel
# QDarkStyle                      3.0.2                3.1         wheel
# qstylizer                       0.1.10               0.2.2       wheel
# QtAwesome                       1.0.2                1.2.2       wheel
# qtconsole                       5.1.1                5.4.0       wheel
# QtPy                            1.10.0               2.3.0       wheel
# regex                           2021.8.3             2022.10.31  wheel
# requests                        2.26.0               2.28.2      wheel
# rope                            0.19.0               1.7.0       wheel
# Rtree                           0.9.7                1.0.1       wheel
# scikit-image                    0.18.3               0.19.3      wheel
# scikit-learn                    0.24.2               1.2.1       wheel
# scikit-learn-intelex            2021.20210714.120553 2023.0.1    wheel
# scipy                           1.7.1                1.10.1      wheel
# seaborn                         0.11.2               0.12.2      wheel
# setuptools                      58.0.4               67.3.2      wheel
# singledispatch                  3.7.0                4.0.0       wheel
# sip                             4.19.13              6.7.7       wheel
# sniffio                         1.2.0                1.3.0       wheel
# snowballstemmer                 2.1.0                2.2.0       wheel
# soupsieve                       2.2.1                2.4         wheel
# Sphinx                          4.2.0                6.1.3       wheel
# sphinxcontrib-applehelp         1.0.2                1.0.4       wheel
# sphinxcontrib-htmlhelp          2.0.0                2.0.1       wheel
# spyder                          5.1.5                5.4.2       wheel
# spyder-kernels                  2.1.3                2.4.2       wheel
# SQLAlchemy                      1.4.22               2.0.4       wheel
# statsmodels                     0.12.2               0.13.5      wheel
# sympy                           1.9                  1.11.1      wheel
# tables                          3.6.1                3.8.0       wheel
# TBB                             0.2                  2021.7.1    wheel
# tensorboard                     2.11.2               2.12.0      wheel
# tensorboard-data-server         0.6.1                0.7.0       wheel
# terminado                       0.9.4                0.17.1      wheel
# testpath                        0.5.0                0.6.0       wheel
# textdistance                    4.2.1                4.5.0       wheel
# threadpoolctl                   2.2.0                3.1.0       wheel
# tifffile                        2021.7.2             2023.2.3    wheel
# toolz                           0.11.1               0.12.0      wheel
# tornado                         6.1                  6.2         wheel
# tqdm                            4.62.3               4.64.1      wheel
# traitlets                       5.1.0                5.9.0       wheel
# typed-ast                       1.4.3                1.5.4       wheel
# typing-extensions               3.10.0.2             4.5.0       wheel
# ujson                           4.0.2                5.7.0       wheel
# Unidecode                       1.2.0                1.3.6       wheel
# uritemplate                     3.0.1                4.1.1       wheel
# urllib3                         1.26.7               1.26.14     wheel
# watchdog                        2.1.3                2.2.1       wheel
# wcwidth                         0.2.5                0.2.6       wheel
# Werkzeug                        2.0.2                2.2.3       wheel
# wheel                           0.37.0               0.38.4      wheel
# widgetsnbextension              3.5.1                4.0.5       wheel
# wrapt                           1.12.1               1.14.1      wheel
# XlsxWriter                      3.0.1                3.0.8       wheel
# xlwings                         0.24.9               0.29.1      wheel
# xmltodict                       0.12.0               0.13.0      wheel
# yapf                            0.31.0               0.32.0      wheel
# zict                            2.0.0                2.2.0       wheel
# zipp                            3.6.0                3.14.0      wheel
# zope.event                      4.5.0                4.6         wheel
# zope.interface                  5.4.0                5.5.2       wheel

# %%
pip install notebook
# Out:
# Requirement already satisfied: notebook in c:\users\nicole.leung\anaconda3\lib\site-packages (6.1.5)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (4.8.1)
# Requirement already satisfied: ipykernel in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (6.4.1)
# Requirement already satisfied: jinja2 in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (2.11.3)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (6.1.12)
# Requirement already satisfied: nbformat in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (5.1.3)
# Requirement already satisfied: ipython-genutils in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (0.2.0)
# Requirement already satisfied: tornado>=5.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (6.1)
# Requirement already satisfied: argon2-cffi in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (6.1.0)
# Requirement already satisfied: prometheus-client in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (0.9.4)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (5.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (22.2.1)
# Requirement already satisfied: Send2Trash in c:\users\nicole.leung\anaconda3\lib\site-packages (from notebook) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\nicole.leung\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook) (228)
# Requirement already satisfied: six>=1.5 in c:\users\nicole.leung\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=5.3.4->notebook) (1.16.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\nicole.leung\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from argon2-cffi->notebook) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\nicole.leung\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook) (2.20)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipykernel->notebook) (7.29.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipykernel->notebook) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipykernel->notebook) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (0.18.0)
# Requirement already satisfied: pickleshare in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (3.0.20)
# Requirement already satisfied: pygments in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (2.10.0)
# Requirement already satisfied: decorator in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (5.1.0)
# Requirement already satisfied: backcall in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (0.2.0)
# Requirement already satisfied: colorama in c:\users\nicole.leung\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->notebook) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\nicole.leung\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->notebook) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\nicole.leung\anaconda3\lib\site-packages (from jinja2->notebook) (1.1.1)
# Requirement already satisfied: testpath in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbconvert->notebook) (0.5.0)
# Requirement already satisfied: bleach in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbconvert->notebook) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbconvert->notebook) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbconvert->notebook) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbconvert->notebook) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbconvert->notebook) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbconvert->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbconvert->notebook) (0.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\nicole.leung\anaconda3\lib\site-packages (from nbformat->notebook) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\nicole.leung\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook) (21.2.0)
# Requirement already satisfied: packaging in c:\users\nicole.leung\anaconda3\lib\site-packages (from bleach->nbconvert->notebook) (21.0)
# Requirement already satisfied: webencodings in c:\users\nicole.leung\anaconda3\lib\site-packages (from bleach->nbconvert->notebook) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nicole.leung\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# absl-py                            1.4.0
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.1
# anaconda-project                   0.10.1
# anyio                              2.2.0
# apache-beam                        2.44.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             4.0.0
# bokeh                              2.4.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# cachetools                         4.2.4
# certifi                            2021.10.8
# cffi                               1.14.6
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              8.0.3
# cloudpickle                        2.2.1
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.10
# conda                              4.10.3
# conda-build                        3.21.6
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# crcmod                             1.7
# cryptography                       3.4.8
# cycler                             0.10.0
# Cython                             0.29.24
# cytoolz                            0.11.0
# daal4py                            2021.3.0
# dask                               2021.10.0
# debugpy                            1.4.1
# decorator                          5.1.0
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# dill                               0.3.1.1
# distributed                        2021.10.0
# docopt                             0.6.2
# docutils                           0.17.1
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# fastavro                           1.7.1
# fastcache                          1.1.0
# fasteners                          0.18
# filelock                           3.3.1
# flake8                             3.9.2
# Flask                              1.1.2
# flatbuffers                        23.1.21
# fonttools                          4.25.0
# fsspec                             2021.10.1
# future                             0.18.2
# gast                               0.4.0
# gevent                             21.8.0
# glob2                              0.7
# google-api-core                    2.11.0
# google-api-python-client           1.12.11
# google-apitools                    0.5.31
# google-auth                        2.16.0
# google-auth-httplib2               0.1.0
# google-auth-oauthlib               0.4.6
# google-cloud-bigquery              3.5.0
# google-cloud-bigquery-storage      2.13.2
# google-cloud-bigtable              1.7.3
# google-cloud-core                  2.3.2
# google-cloud-datastore             1.15.5
# google-cloud-dlp                   3.11.1
# google-cloud-language              1.3.2
# google-cloud-pubsub                2.14.1
# google-cloud-pubsublite            1.6.0
# google-cloud-recommendations-ai    0.7.1
# google-cloud-spanner               3.27.1
# google-cloud-videointelligence     1.16.3
# google-cloud-vision                3.3.1
# google-crc32c                      1.5.0
# google-pasta                       0.2.0
# google-resumable-media             2.4.1
# googleapis-common-protos           1.58.0
# greenlet                           1.1.1
# grpc-google-iam-v1                 0.12.6
# grpcio                             1.51.1
# grpcio-status                      1.48.2
# h5py                               3.2.1
# hdfs                               2.7.0
# HeapDict                           1.0.1
# html5lib                           1.1
# httplib2                           0.20.4
# idna                               3.2
# imagecodecs                        2021.8.26
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 4.8.1
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.4.1
# ipython                            7.29.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isort                              5.9.3
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.18.0
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# joblib                             1.2.0
# json5                              0.9.6
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.8.1
# jupyter-server                     1.4.1
# jupyterlab                         3.2.1
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 1.0.0
# keras                              2.11.0
# keyring                            23.1.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# libclang                           15.0.6.1
# llvmlite                           0.37.0
# locket                             0.2.1
# lxml                               4.6.3
# Markdown                           3.4.1
# MarkupSafe                         1.1.1
# matplotlib                         3.4.3
# matplotlib-inline                  0.1.2
# mccabe                             0.6.1
# menuinst                           1.4.18
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.10.0
# MouseInfo                          0.1.3
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# munkres                            1.1.4
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.3
# nltk                               3.6.5
# nose                               1.3.7
# notebook                           6.1.5
# numba                              0.54.1
# numexpr                            2.7.3
# numpy                              1.20.3
# numpydoc                           1.1.0
# oauth2client                       4.1.3
# oauthlib                           3.2.2
# objsize                            0.6.1
# olefile                            0.46
# opencv-python                      4.7.0.68
# openpyxl                           3.0.9
# opt-einsum                         3.3.0
# orjson                             3.8.6
# overrides                          6.5.0
# packaging                          21.0
# pandas                             1.3.4
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.7.0
# patsy                              0.5.2
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                21.2.4
# pkginfo                            1.7.1
# pluggy                             0.13.1
# ply                                3.11
# poyo                               0.5.0
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.20
# proto-plus                         1.22.2
# protobuf                           3.19.6
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pyarrow                            6.0.1
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# PyAutoGUI                          0.9.53
# pycodestyle                        2.7.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.44.1
# pydocstyle                         6.1.1
# pydot                              1.4.2
# pyerfa                             2.0.0
# pyfarmhash                         0.3.2
# pyflakes                           2.3.1
# PyGetWindow                        0.0.9
# Pygments                           2.10.0
# PyJWT                              2.1.0
# pylint                             2.9.6
# pyls-spyder                        0.4.0
# pymongo                            3.13.0
# PyMsgBox                           1.0.9
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.4
# pyperclip                          1.8.2
# pyreadline                         2.1
# PyRect                             0.2.0
# pyrsistent                         0.18.0
# PyScreeze                          0.1.28
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-lsp-black                   1.0.0
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.2.4
# python-slugify                     5.0.2
# pytweening                         1.0.4
# pytz                               2021.3
# PyWavelets                         1.1.1
# pywin32                            228
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             6.0
# pyzmq                              22.2.1
# QDarkStyle                         3.0.2
# qstylizer                          0.1.10
# QtAwesome                          1.0.2
# qtconsole                          5.1.1
# QtPy                               1.10.0
# regex                              2021.8.3
# requests                           2.26.0
# requests-oauthlib                  1.3.1
# rope                               0.19.0
# rsa                                4.9
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.3
# scikit-learn                       0.24.2
# scikit-learn-intelex               2021.20210714.120553
# scipy                              1.7.1
# seaborn                            0.11.2
# Send2Trash                         1.8.0
# setuptools                         58.0.4
# simplegeneric                      0.8.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.1.5
# spyder-kernels                     2.1.3
# SQLAlchemy                         1.4.22
# sqlparse                           0.4.3
# statsmodels                        0.12.2
# sympy                              1.9
# tables                             3.6.1
# TBB                                0.2
# tblib                              1.7.0
# tensorboard                        2.11.2
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.1
# tensorflow                         2.11.0
# tensorflow-data-validation         1.12.0
# tensorflow-estimator               2.11.0
# tensorflow-intel                   2.11.0
# tensorflow-io-gcs-filesystem       0.30.0
# tensorflow-metadata                1.12.0
# tensorflow-serving-api             2.11.0
# termcolor                          2.2.0
# terminado                          0.9.4
# testpath                           0.5.0
# text-unidecode                     1.3
# textdistance                       4.2.1
# tfx-bsl                            1.12.0
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.7.2
# tinycss                            0.4
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.62.3
# traitlets                          5.1.0
# typed-ast                          1.4.3
# typing-extensions                  3.10.0.2
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# uritemplate                        3.0.1
# urllib3                            1.26.7
# watchdog                           2.1.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           2.0.2
# wheel                              0.37.0
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwings                            0.24.9
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.6.0
# zope.event                         4.5.0
# zope.interface                     5.4.0
# zstandard                          0.19.0
