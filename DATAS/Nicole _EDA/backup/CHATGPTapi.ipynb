# %%
import openai
import os

# 设置OpenAI API访问密钥
openai.api_key = "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"

# %%
# 调用ChatGPT API生成对话文本
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt="Hello, how are you today?",
    max_tokens=50,
    n=1,
    stop=None,
    temperature=0.5,
)

# 从响应中提取生成的对话文本
text = response.choices[0].text.strip()

# 打印生成的对话文本
print(text)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# c:\Users\Nicole.Leung\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\Users\Nicole.Leung\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# c:\Users\Nicole.Leung\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
# ...

# %%
import requests
import json

# Set the API endpoint and access token
api_endpoint = "https://api.openai.com/v1/engines/davinci-codex/completions"
access_token = "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"

# Set the prompt text and parameters
prompt_text = "Hello, how are you today?"
params = {
    "prompt": prompt_text,
    "temperature": 0.7,
    "max_tokens": 60,
    "top_p": 1,
    "frequency_penalty": 0.5,
    "presence_penalty": 0.0
}

# Send the API request
headers = {"Content-Type": "application/json",
           "Authorization": f"Bearer {access_token}"}
response = requests.post(api_endpoint, headers=headers, json=params)

# Process the API response
if response.status_code == 200:
    response_text = json.loads(response.text)["choices"][0]["text"]
    print(f"ChatGPT response: {response_text}")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# c:\Users\Nicole.Leung\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\Users\Nicole.Leung\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# c:\Users\Nicole.Leung\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
# ...
