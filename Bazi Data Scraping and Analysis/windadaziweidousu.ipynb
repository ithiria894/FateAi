# %%
from selenium import webdriver
import time
from selenium.webdriver.support.ui import Select
driver = webdriver.Chrome()

from selenium.webdriver.common.by import By

# %%
year="2000"
month="5"
day="5"
hr="17"
# minute=29
gender="F"

# %%
#conver all to string
year=str(year)
month=str(month)
day=str(day)
hr=str(hr)

# %%
driver.get("https://fate.windada.com/cgi-bin/fate")
# select = Select(driver.find_element(By.NAME, "hityear"))
# select.select_by_value(year)

#input year to id="bYear"
# use driver.find_element(By.ID,
driver.find_element(By.ID,'bYear').send_keys(year)

select = Select(driver.find_element(By.NAME, "Month"))
select.select_by_value(month)

select = Select(driver.find_element(By.NAME, "Day"))
select.select_by_value(day)

select = Select(driver.find_element(By.NAME, "Hour"))
select.select_by_value(hr)
# select.select_by_visible_text(hr)

if gender == "M":
    driver.find_elements(By.ID,'bMale')[0].click()
    #click on the radio button by class="myradio"
    # driver.find_element_by_css_selector("input[type='radio'][value='1']").click()
    # modify he above line to make it work, there s AttributeError: 'WebDriver' object has no attribute 'find_element_by_css_selector'


if gender =="F":
    driver.find_elements(By.ID,'bFemale')[0].click()
#make the window full screen
driver.maximize_window()
driver.find_elements(By.CSS_SELECTOR,"input[type='submit']")[0].click()

#     returnv=driver.find_elements(By.XPATH,"//font[@size = '6' and @face='標楷體']")

# %%
#GET PAST 桃花 only
前十流年="2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025,2026,2027,2028,2029,2030,2031,2032"
前十流年=前十流年.split(",")
# print(流年)
for liunian in 前十流年:
    select = Select(driver.find_element(By.NAME, "FateYear"))
    select.select_by_value(str(liunian))
    # <input type="button" value="流年" name="calyear" onclick="checkFunc(3,0)">
    driver.find_elements(By.CSS_SELECTOR,"input[type='button'][value='流年']")[0].click()

    #get all the td elements using the above xpath
    trs=driver.find_elements(By.XPATH,"/html/body/div[2]/div/article/form/table[2]/tbody/tr")
    # get only width=25% td elements
    tds=driver.find_elements(By.XPATH,"/html/body/div[2]/div/article/form/table[2]/tbody/tr/td[@width='25%']")
    #get all the td elements by xpath from trs
    # tds=driver.find_elements(By.XPATH,"/html/body/div[2]/div/article/form/table[2]/tbody/tr/td")
    HongLianGong=""
    TianXiGong=""
    print(liunian," 流年：-------------------------------------------------------------------------------------")
    for td in tds:
        # print(td.text)
        #check if 紅鸞 is in the td.text
        if "流鸞" in td.text:
            # print(td.text)
            #get the gong name from the td.text, which is within【 】
            HongLianGong=td.text.split("【")[1].split("】")[0]
            print("流鸞 in",HongLianGong)
        if "流喜" in td.text:
            TianXiGong=td.text.split("【")[1].split("】")[0]
            print("流喜 in",TianXiGong)
        # print("-----")
    
    

    # trs=driver.find_element(By.XPATH,"/html/body/div[2]/div/article/form/table[4]/tbody")
    # print(trs.text)

    # detail=driver.find_element(By.XPATH,"/html/body/div[2]/div/article/form/table[5]")
    # print(detail.text)
# Out:
# 2010  流年：-------------------------------------------------------------------------------------
# 流喜 in 兄弟宮
# 流鸞 in 交友宮
# 2011  流年：-------------------------------------------------------------------------------------
# 流喜 in 夫妻宮
# 流鸞 in 事業宮
# 2012  流年：-------------------------------------------------------------------------------------
# 流喜 in 子女宮
# 流鸞 in 田宅宮
# 2013  流年：-------------------------------------------------------------------------------------
# 流喜 in 財帛宮
# 流鸞 in 福德宮
# 2014  流年：-------------------------------------------------------------------------------------
# 流鸞 in 父母宮
# 流喜 in 疾厄宮
# 2015  流年：-------------------------------------------------------------------------------------
# 流鸞 in 命宮
# 流喜 in 遷移宮-身宮
# 2016  流年：-------------------------------------------------------------------------------------
# 流鸞 in 兄弟宮
# 流喜 in 交友宮
# 2017  流年：-------------------------------------------------------------------------------------
# 流鸞 in 夫妻宮
# 流喜 in 事業宮
# 2018  流年：-------------------------------------------------------------------------------------
# 流鸞 in 子女宮
# 流喜 in 田宅宮
# 2019  流年：-------------------------------------------------------------------------------------
# 流鸞 in 財帛宮
# 流喜 in 福德宮
# 2020  流年：-------------------------------------------------------------------------------------
# 流喜 in 父母宮
# 流鸞 in 疾厄宮
# 2021  流年：-------------------------------------------------------------------------------------
# 流喜 in 命宮
# 流鸞 in 遷移宮-身宮
# 2022  流年：-------------------------------------------------------------------------------------
# 流喜 in 兄弟宮
# 流鸞 in 交友宮
# 2023  流年：-------------------------------------------------------------------------------------
# 流喜 in 夫妻宮
# 流鸞 in 事業宮
# 2024  流年：-------------------------------------------------------------------------------------
# 流喜 in 子女宮
# 流鸞 in 田宅宮
# 2025  流年：-------------------------------------------------------------------------------------
# 流喜 in 財帛宮
# 流鸞 in 福德宮
# 2026  流年：-------------------------------------------------------------------------------------
# 流鸞 in 父母宮
# 流喜 in 疾厄宮
# 2027  流年：-------------------------------------------------------------------------------------
# 流鸞 in 命宮
# 流喜 in 遷移宮-身宮
# 2028  流年：-------------------------------------------------------------------------------------
# 流鸞 in 兄弟宮
# 流喜 in 交友宮
# 2029  流年：-------------------------------------------------------------------------------------
# 流鸞 in 夫妻宮
# 流喜 in 事業宮
# 2030  流年：-------------------------------------------------------------------------------------
# 流鸞 in 子女宮
# 流喜 in 田宅宮
# 2031  流年：-------------------------------------------------------------------------------------
# 流鸞 in 財帛宮
# 流喜 in 福德宮
# 2032  流年：-------------------------------------------------------------------------------------
# 流喜 in 父母宮
# 流鸞 in 疾厄宮

# %%
流年="2022,2023,2024,2025,2026,2027,2028,2029,2030,2031,2032"
流年=流年.split(",")
# print(流年)
for liunian in 流年:
    select = Select(driver.find_element(By.NAME, "FateYear"))
    select.select_by_value(str(liunian))
    # <input type="button" value="流年" name="calyear" onclick="checkFunc(3,0)">
    driver.find_elements(By.CSS_SELECTOR,"input[type='button'][value='流年']")[0].click()

    #get all the td elements using the above xpath
    trs=driver.find_elements(By.XPATH,"/html/body/div[2]/div/article/form/table[2]/tbody/tr")
    # get only width=25% td elements
    tds=driver.find_elements(By.XPATH,"/html/body/div[2]/div/article/form/table[2]/tbody/tr/td[@width='25%']")
    #get all the td elements by xpath from trs
    # tds=driver.find_elements(By.XPATH,"/html/body/div[2]/div/article/form/table[2]/tbody/tr/td")
    HongLianGong=""
    TianXiGong=""
    print(liunian," 流年：-------------------------------------------------------------------------------------")
    for td in tds:
        # print(td.text)
        #check if 紅鸞 is in the td.text
        if "流鸞" in td.text:
            # print(td.text)
            #get the gong name from the td.text, which is within【 】
            HongLianGong=td.text.split("【")[1].split("】")[0]
            print("流鸞 in",HongLianGong)
        if "流喜" in td.text:
            TianXiGong=td.text.split("【")[1].split("】")[0]
            print("流喜 in",TianXiGong)
        # print("-----")
    
    

    trs=driver.find_element(By.XPATH,"/html/body/div[2]/div/article/form/table[4]/tbody")
    print(trs.text)

    detail=driver.find_element(By.XPATH,"/html/body/div[2]/div/article/form/table[5]")
    print(detail.text)
# Out:
# 2022  流年：-------------------------------------------------------------------------------------
# 流喜 in 兄弟宮
# 流鸞 in 交友宮
# 【紫府同宮格】 紫微、天府二帝同宮，貴氣重，但紫微性質為積極進取，天府性質為穩重保守，步調不一。故不能果斷下決策，延誤搶得先機機會。
# 【府相朝垣格】 可衣食無憂。若為官或做主管，則機運佳。
# 【祿馬交馳格】 主奔波勞碌而招財。
# 【命裡逢空格】 有精神上孤獨，錢不易留住之跡象。
# 【馬落空亡】 奔波，空忙一場。
# 格局總數 共3吉2兇
# 紫微 紫微在流年：有利於公務員及白領階級的仕途陞遷。學生學業順利。經商者擴展規模、客源不絕、財源不斷。政治人物的從政發展
# ◎因與天府同宮，可得貴人幫助，因而名利雙收。
# ◎因逢空劫，有經濟困難、破財停滯的不利。
# 天府 天府在流年：財運強，利於事業的發展，穩定中求進步。有陞遷加薪機會。做事順利。有逢凶化吉的作用。
# 地空 地空：指精神上破秏。在感情上可能有不利的影響。
# 流年權 流年權：有主動爭取掌權的慾望，也有機會穫得權力、威望、能力等。
# 大限權 大限權：有主動爭取掌權的慾望，也有機會穫得權力、威望、能力等。
# 天馬 天馬：驛馬、變動。
# 天哭 天哭：感情上打擾，損秏。
# 天月 天月：醫藥，疾病，詬病，怪癖，遭受詬病或惡性詆毀。
# 飛廉 飛廉：破壞，飛來是非。
# 流昌 流昌：利於考試通過、職務陞遷。女命又主有生產喜事。
# 歲建 歲建：逢吉增吉，逢凶增凶
# 指背 指背：應防背後遭人誹謗、中傷。
# 2023  流年：-------------------------------------------------------------------------------------
# 流喜 in 夫妻宮
# 流鸞 in 事業宮
# 【科名會祿格】 才華卓越，步入社會發展，可獲擢昇。
# 格局總數 共1吉0兇
# 太陰 太陰在流年：有財源，金錢能積存。事業上有發展，受薪階級能有晉陞機會。能認識喜歡類型的對象。對於已進行中的感情，也會瀰漫著一種浪漫幸福感。利於嫁娶，生產。
# ◎因遇有吉星，主得意外財富、婚嫁、添子，事業發展。
# 化科 化科：可得貴人、科名、教化。動爭取功名，但有雷聲大雨點小之象。
# 流年科 流年科：可得貴人、科名、教化。
# 台輔 台輔：偷竊性質、聲望、臺閣之星。
# 奏書 奏書：上訴，化祿見祿為上訴得直，獎賞，聘書。
# 流昌 流昌：利於考試通過、職務陞遷。女命又主有生產喜事。
# 歲建 歲建：逢吉增吉，逢凶增凶
#

# 歲建 歲建：逢吉增吉，逢凶增凶
# 將星 將星：可得到他人援助，事情進行順利。
# 2030  流年：-------------------------------------------------------------------------------------
# 流鸞 in 子女宮
# 流喜 in 田宅宮
# 【將星得地格】 大器晚成，少年運勢較不利，三十歲後漸能逐步發達。
# 格局總數 共1吉0兇
# 武曲 武曲在流年：有財源，事業推展順利，能達到預期目標。利於經商者的事業拓展，受薪階級能有加薪機會
# 化權 化權：有主動爭取掌權的慾望，也有機會穫得權力、威望、能力等。
# 流年權 流年權：有主動爭取掌權的慾望，也有機會穫得權力、威望、能力等。
# 大限忌 大限忌：會有是非、管閒事、困擾、損失、虧欠、糾纏。自找痳煩。主遭遇災禍。
# 天虛 天虛：物質上損秏。
# 解神 解神：分解，一分為二，解神見天馬即離婚。
# 伏兵 伏兵：隱藏之患。
# 歲建 歲建：逢吉增吉，逢凶增凶
# 華蓋 華蓋：多空想、少實行。利於宗教、命理、學術的創作。
# 2031  流年：-------------------------------------------------------------------------------------
# 流鸞 in 財帛宮
# 流喜 in 福德宮
# 【三奇嘉會格】 化祿、化權、化科三化曜合稱為三奇。
# 【權祿巡逢格】 利於事業穩定發展經營。
# 格局總數 共2吉0兇
# 太陽 太陽在流年：在工作事業上處於忙碌、競爭的狀態，是個人在部門團體內力求表現的時候。若能順利完成任務，給予上級深刻印象，往後則有陞遷加薪的機會。單身男女有結識對象的機會。錢財開銷較往常大了點。
# 火星 火星：有事情急劇變化，不利於事情進展。應提防是非及精神上面臨紛擾，不愉快。
# 化祿 化祿：可得錢財、貴人。主動爭取財利，順利成功。
# 流年權 流年權：有主動爭取掌權的慾望，也有機會穫得權力、威望、能力等。
# 大限權 大限權：有主動爭取掌權的慾望，也有機會穫得權力、威望、能力等。
# 天官 天官：有貴人幫助，但助力比天魁天鉞低些。
# 紅鸞 紅鸞：主桃花運。有認識異性機會或有喜訊。一般指追逐愛情開始。
# 天巫 天巫：神怪，遺產，靈界物，媒介物，有人介紹，積聚，收集性質。
# 封誥 封誥：利考試，地位,封贈，封章之星。
# 大耗 大耗：損失。如失竊破財。
# 歲建 歲建：逢吉增吉，逢凶增凶
# 指背 指背：應防背後遭人誹謗、中傷。
# 2032  流年：-------------------------------------------------------------------------------------
# 流喜 in 父母宮
# 流鸞 in 疾厄宮
# 【英星入廟格】 有領導力，喜冒險犯難，具開創精神。
# 格局總數 共1吉0兇
# 破軍 破軍在流年：會因為對現況不滿或不想安於現況，多少有著做了再說的衝動性，會有‘先斬後奏’的行為。主去舊換新。有新的發展契機。從事專門技術的人有很好突破的成功機會。所處的週遭的環境、人事或事業方面，都可能面臨較大的變動。
# ◎因遇吉星，有去舊換新，另謀新機或出門旅行機會。
# 天刑 天刑：自律，受控制。會見化忌或凶星，反會失控，助紂為虐。主刑剋、孤單或分離
# 病符 病符：注意小病。
# 流羊 流羊：主不和、分離、糾紛等事情。
# 歲建 歲建：逢吉增吉，逢凶增凶
# 將星 將星：可得到他人援助，事情進行順利。

# %%
流年=2022
#select 流年 in name="FateYear"
select = Select(driver.find_element(By.NAME, "FateYear"))
select.select_by_value(str(流年))
# <input type="button" value="流年" name="calyear" onclick="checkFunc(3,0)">
driver.find_elements(By.CSS_SELECTOR,"input[type='button'][value='流年']")[0].click()

# %%
# /html/body/div[2]/div/article/form/table[2]/tbody/tr[1]/td
#get all the td elements using the above xpath
trs=driver.find_elements(By.XPATH,"/html/body/div[2]/div/article/form/table[2]/tbody/tr")
# get only width=25% td elements
tds=driver.find_elements(By.XPATH,"/html/body/div[2]/div/article/form/table[2]/tbody/tr/td[@width='25%']")
#get all the td elements by xpath from trs
# tds=driver.find_elements(By.XPATH,"/html/body/div[2]/div/article/form/table[2]/tbody/tr/td")
for td in tds:
    # print(td.text)
    #check if 紅鸞 is in the td.text
    if "紅鸞" in td.text:
        #get the gong name from the td.text, which is within【 】
        HongLianGong=td.text.split("【")[1].split("】")[0]
    if "天喜" in td.text:
        TianXiGong=td.text.split("【")[1].split("】")[0]
    # print("-----")
print("紅鸞 in",HongLianGong)
print("天喜 in",TianXiGong)
# Out:
# 紅鸞 in 田宅宮
# 天喜 in 子女宮

# %%
# /html/body/div[2]/div/article/form/table[4]
#get the elements in the above xpath
trs=driver.find_element(By.XPATH,"/html/body/div[2]/div/article/form/table[4]/tbody")
print(trs.text)
# Out:
# 【紫府同宮格】 紫微、天府二帝同宮，貴氣重，但紫微性質為積極進取，天府性質為穩重保守，步調不一。故不能果斷下決策，延誤搶得先機機會。
# 【府相朝垣格】 可衣食無憂。若為官或做主管，則機運佳。
# 【祿馬交馳格】 主奔波勞碌而招財。
# 【命裡逢空格】 有精神上孤獨，錢不易留住之跡象。
# 【馬落空亡】 奔波，空忙一場。
# 格局總數 共3吉2兇

# %%
detail=driver.find_element(By.XPATH,"/html/body/div[2]/div/article/form/table[5]")
print(detail.text)
# Out:
# 紫微 紫微在流年：有利於公務員及白領階級的仕途陞遷。學生學業順利。經商者擴展規模、客源不絕、財源不斷。政治人物的從政發展
# ◎因與天府同宮，可得貴人幫助，因而名利雙收。
# ◎因逢空劫，有經濟困難、破財停滯的不利。
# 天府 天府在流年：財運強，利於事業的發展，穩定中求進步。有陞遷加薪機會。做事順利。有逢凶化吉的作用。
# 地空 地空：指精神上破秏。在感情上可能有不利的影響。
# 流年權 流年權：有主動爭取掌權的慾望，也有機會穫得權力、威望、能力等。
# 大限權 大限權：有主動爭取掌權的慾望，也有機會穫得權力、威望、能力等。
# 天馬 天馬：驛馬、變動。
# 天哭 天哭：感情上打擾，損秏。
# 天月 天月：醫藥，疾病，詬病，怪癖，遭受詬病或惡性詆毀。
# 飛廉 飛廉：破壞，飛來是非。
# 流昌 流昌：利於考試通過、職務陞遷。女命又主有生產喜事。
# 歲建 歲建：逢吉增吉，逢凶增凶
# 指背 指背：應防背後遭人誹謗、中傷。
