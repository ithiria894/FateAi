# %%
import sys
sys.path.append(r"C:\Users\Atlas\Documents\GitHub\FateAi\CrystalMarch\bazi")
# import main
import metaphysic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5480\794059774.py in <module>
#       2 sys.path.append(r"C:\Users\Atlas\Documents\GitHub\FateAi\CrystalMarch\bazi")
#       3 # import main
# ----> 4 import metaphysic
#
# ModuleNotFoundError: No module named 'metaphysic'

# %%
ba=metaphysic.bazi(1996,9,17,3)
ba=ba.split("-")
bazi=[]
for i in ba:
    # print(i.split())
    bazi.append(i[0])
    bazi.append(i[1])
bazi
# Out:
# changed sth
# 输入:[1996-9-17]; 输出:[1996-8-5]; 天干地支:[丙子-丁酉-丁巳]; 生肖:[鼠]
# ['丙', '子', '丁', '酉', '丁', '巳', '壬', '寅']

# %%
# make a df with the following cols: 年干 年支 月干 月支 日干 日支 时干 时支 only
import pandas as pd
# df = pd.DataFrame(data,columns=['Name','Gender',"BirthyYear","Bmonth","Bday","FatherDeadY"])

bazidf=pd.DataFrame(columns=["年干","年支","月干","月支","日干","日支","时干","时支"])
# bazidf.columns=["年干","年支","月干","月支","日干","日支","时干","时支"]

# %%
bazidf
# Out:
# Empty DataFrame
# Columns: [年干, 年支, 月干, 月支, 日干, 日支, 时干, 时支]
# Index: []

# %%
# add bazi to bazidf
bazidf.loc[0]=bazi
bazidf
# Out:
#   年干 年支 月干 月支 日干 日支 时干 时支
# 0  丙  子  丁  酉  丁  巳  壬  寅
