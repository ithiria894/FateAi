# %%
from opencc import OpenCC
cc = OpenCC('s2hk')
import regex as re


# 初始化OpenCC转换器
cc = OpenCC('s2hk')

def convert_text(text):
    # 确保只处理字符串类型的变量
    if isinstance(text, str):
        # 替换文本中的指定词汇
        text = text.replace('您', '你').replace('他', '對方')
        # 进行繁体转换
        text = cc.convert(text)
    return text

def 合盤回復(命主, 命主資料, 合盤對象資料, 感情觀及性格, 要留意的地方,危機年份,命盤幫助,你的年份預測,對方的年份預測):

 # 创建一个包含所有变量的列表
    allvariable = [命主, 命主資料, 合盤對象資料, 感情觀及性格, 要留意的地方, 危機年份, 命盤幫助, 你的年份預測, 對方的年份預測]

    # 使用循环替换文本并转换为繁体中文
    for index, value in enumerate(allvariable):
        modified_value = value.replace('您', '你').replace('他', '對方')
        modified_value = cc.convert(modified_value)
        allvariable[index] = modified_value

    # 从修改后的列表中取回修改后的值
    (命主, 命主資料, 合盤對象資料, 感情觀及性格, 要留意的地方, 危機年份, 命盤幫助, 你的年份預測, 對方的年份預測) = allvariable



    text = f'''
命主：{命主}
命主資料：{命主資料}
合盤對象資料：{合盤對象資料}

Plan：合盤

你好，批命已完成，命盤解讀會以語音輔以文字為你批命。
由於我的預測內容相當詳盡且包含了許多年份的細緻預測，因此透過文字和語音記錄，你可以方便地保存下來，以便在需要的時候睇翻。
請先等我解讀完畢先開始提問，提問沒有時間限制，希望可以對你有幫助。

首先我會解讀雙方在感情中的態度和相互對待關係。
    {感情觀及性格}

接下來我會解讀關於你們的雙方命盤對對方的影響。請留意，這和性格沒有關係，和雙方是否正緣也沒有關係，是一些客觀的影響，長期一起生活才會開始展現以下的特質。
    {命盤幫助}
    
接下來我會指出一些你們之間相處需要留意的地方。請留意，一開始或短期相處未必會出現這些問題，長期一起生活才會容易發生，只要互相理解遷就便能最大程度降低以下的問題。
    {要留意的地方}

接下來，我會提供關於你們感情運的年份預測。這些預測可以給你一些留意的方向。如果在雙方感情運較強的年份，你們感情符合或進一步發展的可能性也會增加。因此，在這樣的時候，你可以進行更多互動和提出要求，以便更好地把握機會。
你的年份預測：
    {你的年份預測}
對方的年份預測：
    {對方的年份預測}
    
*請留意，上面只是點出容易有桃花並且發生感情的年份，並不代表一定會出軌，因為命盤是客觀的，而出軌與否是個人決定。

每個人的命運中，即使是最好的情侶，也難免會遇到感情關係不穩定或爭執的時候。當面臨這些危機年份時，我們建議客戶盡早與伴侶達成共識。只要嗯能度過這些危機時刻，感情就有機會變得更加穩定。
    {危機年份}

批命已完成， 有問題可留言，提問沒有時間限制，希望可以對你有幫助。🙏
    '''
    print(text)

# %%
命主 = 'Wingg'
命主資料= "2002/11/28 10:08 女"
合盤對象資料= "2003/09/25 男"
感情觀及性格 = '''
你好呀，咁呢幫你睇咗你哋兩個盤啦咁首先你哋之間呢個默契度係幾高分㗎係有㗎
但係承諾上邊係爭少少㗎 同埋性吸引力比較少 可能不会有太多激情
咁你哋之間相見嘅時候係每一種比較親密嘅感覺,可能係偏向家人,未必係一種情侶之間嘅激情嘅感覺
而係一種兄弟姊妹般熟悉嘅感覺，而呢一種關係係利於長久發展的
咁你哋情感模式都有強烈嘅相似性包括相似嘅心靈感受同埋情緒波動
包括內心對安全感的需求都係相似嘅
你哋可以互相了解對方嘅諗法產生到一個默契同埋感受到對方嘅情緒波動
可以做到一個心靈溝通嘅摯友，對長久穩定嘅關係非常之有利
咁你哋兩個都幾好傾嘅可以通過語言表達去產生到相處愉快嘅感覺
即係你講一句對方可能就已經知道你下一句要講乜，有呢個溝通上嘅默契
所以即使係情侶你哋嘅關係都會好似一個摯友咁
如果你对對方的关注度不够时，会让對方非常容易引发嫉妒、冲动或霸道的情绪。
你会更多地关注物质层面的东西，而對方更倾向于更为符合道德伦理和理想化的目标。
你们可能会在信仰、出版、金融、法律事物或教育等领域有不同的意见，文化背景可能也有些差异。
很可能在艺术、音乐、戏剧、玄学等领域兴趣相投

'''
命盤幫助 = '''
對方在以下這三個宮位，對你最有幫助。你可以考慮在這些生活領域與對方多些交流，讓兩人關係 1+1>2，共創雙贏與美好的未來：

🥇 第九宮，又稱遷移宮，象徵高等教育、哲學、道德、法律、外國、長途旅行等。對方有機會激發您的研究能量，幫助您探索更高層次的智慧，特別是宗教、修行、真理、哲學、命理等方面。兩人也有機會成為好的旅伴，甚至在國外事務中有良好交流。

🥈 第八宮，又稱疾厄宮，象徵配偶錢財、他方資源、商業合資、死亡、遺產、保險等。對方有機會在合資方面對您產生正面的影響，但若雙方合作的不確定性太高，風險無法控制，則務必要小心保守。除此之外，對方還有機會幫助您探索內在深層心理問題，特別是生死與恐懼相關的議題。

🥉 第一宮，又稱命宮，象徵自己、身體、外貌、稟賦等。對方有機會成為您人生旅途中的貴人，幫助您探索自我、了解自己，並且還有助於您的生涯發展，特別是個人能力、身體健康、外在形象等方面。

'''

要留意的地方 = '''
你們有良好的关系保障，无论谁处于何种理由来结束你们的关系，都不会因此造成永久的伤害和怨恨。
對方经常想教育和约束你，而你却想要逃开，当對方表现出训诫、约束、自私、批评、否定的态度时，你会变得十分沮丧和焦虑，不过如果你能明白對方的初衷只是出于一份爱，那么就能放下一些心理包袱。
你们可能互相感觉被对方欺骗和误导，不管你们在心底是多么真诚，只要一不小心就会产生欺骗怀疑的想法，动摇你们的关系
你会毫不留情地批判和挑剔對方的成就，这样一定程度上会限制和拖延對方的行动脚步。
而對方也会对你漠不关心，挑衅十足；你则态度冰冷、拘谨和霸道，而你们这样做都是有道理的。
不要把很久以前的错误反复的提起

'''
你的年份預測 = '''
2025-2027 適合結婚，或會遇到適合結婚的對象並開始發展並有結婚的打算。
特別是2026年，感情運勢最好，也是婚姻運最旺的一年。
2025，衝到夫妻宮，如果已婚容易在呢年有小爭執，如果未婚也會突然想結婚，比較不是plan好的。

2036-2039 如果錯過上一段，這幾年也是婚姻運勢不錯的一段時間。如已婚容易有婚外情。2037-2038比較明顯。

2049-2050 也是一段婚姻運勢不錯的一段時間。容易有感情比較深的桃花。
'''

對方的年份預測 = '''
2022-2023 有桃花運，容易遇到喜歡的人，但不一定是結婚對象。

2034-2035 適合結婚，或會遇到適合結婚的對象並開始發展並有結婚的打算。

2044-2045 如果錯過上一段，這2年也是婚姻運勢不錯的一段時間。如已婚容易有婚外情。

'''
危機年份 = '''

2031-2033 這幾年感情運勢不好，容易有誤解和摩擦，或雙方容易見少離多，容易有婚姻危機，需要互相體諒包容，才能度過這段時間。
2040-2041 這兩年也是婚姻運勢不好的一段時間，容易有婚姻危機，需要互相體諒包容，才能度過這段時間。

'''
合盤回復(命主, 命主資料, 合盤對象資料, 感情觀及性格, 要留意的地方,危機年份,命盤幫助,你的年份預測,對方的年份預測)
# Out:
# 命主：Wingg
# 命主資料：2002/11/28 10:08 女
# 合盤對象資料：2003/09/25 男
#
# Plan：合盤
#
# 你好，批命已完成，命盤解讀會以語音輔以文字為你批命。
# 由於我的預測內容相當詳盡且包含了許多年份的細緻預測，因此透過文字和語音記錄，你可以方便地保存下來，以便在需要的時候睇翻。
# 請先等我解讀完畢先開始提問，提問沒有時間限制，希望可以對你有幫助。
#
# 首先我會解讀雙方在感情中的態度和相互對待關係。
#
# 你好呀，咁呢幫你睇咗你哋兩個盤啦咁首先你哋之間呢個默契度係幾高分㗎係有㗎
# 但係承諾上邊係爭少少㗎 同埋性吸引力比較少 可能不会有太多激情
# 咁你哋之間相見嘅時候係每一種比較親密嘅感覺,可能係偏向家人,未必係一種情侶之間嘅激情嘅感覺
# 而係一種兄弟姊妹般熟悉嘅感覺，而呢一種關係係利於長久發展的
# 咁你哋情感模式都有強烈嘅相似性包括相似嘅心靈感受同埋情緒波動
# 包括內心對安全感的需求都係相似嘅
# 你哋可以互相了解對方嘅諗法產生到一個默契同埋感受到對方嘅情緒波動
# 可以做到一個心靈溝通嘅摯友，對長久穩定嘅關係非常之有利
# 咁你哋兩個都幾好傾嘅可以通過語言表達去產生到相處愉快嘅感覺
# 即係你講一句對方可能就已經知道你下一句要講乜，有呢個溝通上嘅默契
# 所以即使係情侶你哋嘅關係都會好似一個摯友咁
# 如果你对對方的关注度不够时，会让對方非常容易引发嫉妒、冲动或霸道的情绪。
# 你会更多地关注物质层面的东西，而對方更倾向于更为符合道德伦理和理想化的目标。
# 你们可能会在信仰、出版、金融、法律事物或教育等领域有不同的意见，文化背景可能也有些差异。
# 很可能在艺术、音乐、戏剧、玄学等领域兴趣相投
#
#
#
# 接下來我會解讀關於你們的雙方命盤對對方的影響。請留意，這和性格沒有關係，和雙方是否正緣也沒有關係，是一些客觀的影響，長期一起生活才會開始展現以下的特質。
#
# 對方在以下這三個宮位，對你最有幫助。你可以考慮在這些生活領域與對方多些交流，讓兩人關係 1+1>2，共創雙贏與美好的未來：
#
# ...

# %%
命主 = 'EVA'
命主資料= "1977/02/16 8点半pm 女"
合盤對象資料= "1995/08/17 對方"
感情觀及性格 = '''
你個性好強好爭，脾氣大，敢愛敢恨，易情緒化，但腦筋靈活聰明，有創意，雖人際關係常較緊張，容易有小人，但天生具有公關社交手腕，往往能處理棘手的紛爭。
你有桃花、重感情、不能沒有感情、容易因為感情而影響心情。在工作上而言，容易有異性貴人，故適合從事異性客戶比例較多的工作，發展會比較順利。
你是個天性會努力工作的人，在工作上對自己有很高的期望，也有領導能力與強勢的個性，幾乎是人生以工作事業為目的的人。
你命中的伴侶大多較固執且缺浪漫特質，同時也較為現實或較重視本身的成就，但你本身異性緣還不錯，也有主動追求對象的動力，故對你來說，婚姻感情若不滿意寧可單身，感情往往掌握在自己的手中。
你的本命盤看到你與伴侶的對待方式往往較為剛烈，一拍即合或一拍即散，這是導致感情不穩定的主因，應多退一步讓彼此多點空間思考，感情自然會平順穩定。

相處模式：
你们能弥补彼此性格的不足，拥有共同的理想与人生目标，你们很容易就能融入对方的社交圈子。
你能够在精神层面和灵感上给予對方巨大的帮助，也能抚慰對方纷乱的情绪；而對方能够激发你的行动力，不再懒惰和延迟。
可以看到对方对你有所影响的工位大多数是集中于在福德宫兄弟宫等等，代表对方把你当成是一个朋友，而不是一个情人。
你们彼此的目标和理想都会很雷同，但你们的关系容易建立在友谊里面而不是爱情。
等你影响到对方的宮位是夫妻宫和對方女宮，代表你比较倾向把对方当成是一个潜在的发展对象，你会是比较主动的那一方。
對方会更多地关注物质层面的东西，而你更倾向于更为符合道德伦理和理想化的目标。



速配度：
你们的速配度是 
60%。
你對這段關係的感受：
對方人格魅力：42    不太合
相處和諧度：62    還可以
未來展望的一致性：77    不錯
性吸引力：78      不錯
整體感受：65/100  還可以

對方對這段關係的感受：
對方人格魅力：16    很不合
相處和諧度：91    絕配！
未來展望的一致性：57    不太合
性吸引力：53  不太合
整體感受：54/100  不太合

請留意，以上分數乃根據你們的命盤計算出來，僅供參考，並不代表一定會如此，因為命盤是客觀的，而感情是主觀的，所以命盤只能作為一個參考，而不是絕對的。
'''
感情觀及性格 = re.sub(r'#.*', '', 感情觀及性格)
命盤幫助 = '''
在這三個宮位上，對方對你特別有益。增進這些領域的互動將對彼此的關係大有幫助：

福德宮，代表的是朋友、社群、願望、理想等方面。這個宮位的影響可能使你擴展人際網絡，找到值得交往的朋友或同事，甚至可能協助你達成個人目標，或是在參與公共服務或政治活動中為人們帶來助益。

兄弟宮，與學習、信息交流、短途旅行有關。在這些領域，對方可能會成為你的良師益友，尤其是在網絡、信息技術、語言學習、寫作、溝通和學習等方面。遇到日常生活中的小挑戰時，你可能會發現與對方討論意見特別有幫助。

疾厄宮，涉及第三方資源、商業合作、生死、遺產和保險等。在這方面，對方可能對你在投資和合作上有正面的促進作用。不過，如果涉及風險過高且無法控制的合作，則需謹慎行事。此外，對方也可能助你深入了解自己的內心世界，特別是與生死、恐懼等深層心理議題相關的問題。
'''

要留意的地方 = '''
這個盤顯示你们的关系容易有突然的变化，可能是突然的中止，也可能导致你们的关系一直分分合合。
你们其中的一人或者你们俩有浪费的倾向，而且这也只是相对而言，其实你们俩对待钱的方式都比较随意。
你们之间存在着交流方面的分歧，你会觉得對方不够坦白和真诚，而對方会认为你太过坦白诚实而伤害了自己的感受。后者总是会忽视前者的感情或内心的感受，令前者感到对方的冷漠和无情。

'''
你的年份預測 = '''
2028-2030 適合結婚，或會遇到適合結婚的對象並開始發展並有結婚的打算。
特別是2029年，感情運勢最好，也是婚姻運最旺的一年。
2030，衝到夫妻宮，如果已婚容易在這年有小爭執，如果未婚也會突然想結婚。

2040-2041 如果錯過上一段，這幾年也是桃花運勢不錯的一段時間，容易遇上藍顏知己。

'''

對方的年份預測 = '''

2022-2025 進入姻緣運，或會遇到適合結婚的對象並開始發展並有結婚的打算。此時桃花運旺盛，可能有好幾個潛在對象。

2025-2026 進入談婚論家階段，有機會結婚。

2034-2035 如果錯過上一段，這2年也是婚姻運勢不錯的一段時間。如已婚容易有婚外情。

'''
危機年份 = '''

2031-2032 這幾年感情運勢不好，容易有誤解和摩擦，或雙方容易見少離多，容易有婚姻危機，需要互相體諒包容，才能度過這段時間。
2037-2038 這兩年也是婚姻運勢不好的一段時間，容易有婚姻危機，需要互相體諒包容，才能度過這段時間。

'''
合盤回復(命主, 命主資料, 合盤對象資料, 感情觀及性格, 要留意的地方,危機年份,命盤幫助,你的年份預測,對方的年份預測)
# Out:
# 命主：EVA
# 命主資料：1977/02/16 8點半pm 女
# 合盤對象資料：1995/08/17 對方
#
# Plan：合盤
#
# 你好，批命已完成，命盤解讀會以語音輔以文字為你批命。
# 由於我的預測內容相當詳盡且包含了許多年份的細緻預測，因此透過文字和語音記錄，你可以方便地保存下來，以便在需要的時候睇翻。
# 請先等我解讀完畢先開始提問，提問沒有時間限制，希望可以對你有幫助。
#
# 首先我會解讀雙方在感情中的態度和相互對待關係。
#
# 你個性好強好爭，脾氣大，敢愛敢恨，易情緒化，但腦筋靈活聰明，有創意，雖人際關係常較緊張，容易有小人，但天生具有公關社交手腕，往往能處理棘手的紛爭。
# 你有桃花、重感情、不能沒有感情、容易因為感情而影響心情。在工作上而言，容易有異性貴人，故適合從事異性客户比例較多的工作，發展會比較順利。
# 你是個天性會努力工作的人，在工作上對自己有很高的期望，也有領導能力與強勢的個性，幾乎是人生以工作事業為目的的人。
# 你命中的伴侶大多較固執且缺浪漫特質，同時也較為現實或較重視本身的成就，但你本身異性緣還不錯，也有主動追求對象的動力，故對你來説，婚姻感情若不滿意寧可單身，感情往往掌握在自己的手中。
# 你的本命盤看到你與伴侶的對待方式往往較為剛烈，一拍即合或一拍即散，這是導致感情不穩定的主因，應多退一步讓彼此多點空間思考，感情自然會平順穩定。
#
# 相處模式：
# 你們能彌補彼此性格的不足，擁有共同的理想與人生目標，你們很容易就能融入對方的社交圈子。
# 你能夠在精神層面和靈感上給予對方巨大的幫助，也能撫慰對方紛亂的情緒；而對方能夠激發你的行動力，不再懶惰和延遲。
# 可以看到對方對你有所影響的工位大多數是集中於在福德宮兄弟宮等等，代表對方把你當成是一個朋友，而不是一個情人。
# 你們彼此的目標和理想都會很雷同，但你們的關係容易建立在友誼裏面而不是愛情。
# 等你影響到對方的宮位是夫妻宮和對方女宮，代表你比較傾向把對方當成是一個潛在的發展對象，你會是比較主動的那一方。
# 對方會更多地關注物質層面的東西，而你更傾向於更為符合道德倫理和理想化的目標。
#
#
#
# 速配度：
# 你們的速配度是
# 60%。
# 你對這段關係的感受：
# 對方人格魅力：42    不太合
# 相處和諧度：62    還可以
# ...
