# %%
"""
This code sample shows Prebuilt Invoice operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://docs.microsoft.com/en-us/azure/applied-ai-services/form-recognizer/quickstarts/try-v3-python-sdk
"""
import os
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
# endpoint = "YOUR_FORM_RECOGNIZER_ENDPOINT"
# key = "YOUR_FORM_RECOGNIZER_KEY"
key = "1929a6ca42184125950e33d48ce440fc"
endpoint = "https://testfr.cognitiveservices.azure.com/"
# sample document
formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/invoice_sample.jpg"

document_analysis_client = DocumentAnalysisClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)
    
# poller = document_analysis_client.begin_analyze_document_from_url("prebuilt-invoice", formUrl)

#read from local
local_file = open("C:\\Users\\Administrator\\Desktop\\invoice_sample.jpg", "rb")
poller = document_analysis_client.begin_analyze_document("prebuilt-invoice", local_file)

invoices = poller.result()

for idx, invoice in enumerate(invoices.documents):
    print("--------Recognizing invoice #{}--------".format(idx + 1))
    vendor_name = invoice.fields.get("VendorName")
    if vendor_name:
        print(
            "Vendor Name: {} has confidence: {}".format(
                vendor_name.value, vendor_name.confidence
            )
        )
    vendor_address = invoice.fields.get("VendorAddress")
    if vendor_address:
        print(
            "Vendor Address: {} has confidence: {}".format(
                vendor_address.value, vendor_address.confidence
            )
        )
    vendor_address_recipient = invoice.fields.get("VendorAddressRecipient")
    if vendor_address_recipient:
        print(
            "Vendor Address Recipient: {} has confidence: {}".format(
                vendor_address_recipient.value, vendor_address_recipient.confidence
            )
        )
    customer_name = invoice.fields.get("CustomerName")
    if customer_name:
        print(
            "Customer Name: {} has confidence: {}".format(
                customer_name.value, customer_name.confidence
            )
        )
    customer_id = invoice.fields.get("CustomerId")
    if customer_id:
        print(
            "Customer Id: {} has confidence: {}".format(
                customer_id.value, customer_id.confidence
            )
        )
    customer_address = invoice.fields.get("CustomerAddress")
    if customer_address:
        print(
            "Customer Address: {} has confidence: {}".format(
                customer_address.value, customer_address.confidence
            )
        )
    customer_address_recipient = invoice.fields.get("CustomerAddressRecipient")
    if customer_address_recipient:
        print(
            "Customer Address Recipient: {} has confidence: {}".format(
                customer_address_recipient.value,
                customer_address_recipient.confidence,
            )
        )
    invoice_id = invoice.fields.get("InvoiceId")
    if invoice_id:
        print(
            "Invoice Id: {} has confidence: {}".format(
                invoice_id.value, invoice_id.confidence
            )
        )
    invoice_date = invoice.fields.get("InvoiceDate")
    if invoice_date:
        print(
            "Invoice Date: {} has confidence: {}".format(
                invoice_date.value, invoice_date.confidence
            )
        )
    invoice_total = invoice.fields.get("InvoiceTotal")
    if invoice_total:
        print(
            "Invoice Total: {} has confidence: {}".format(
                invoice_total.value, invoice_total.confidence
            )
        )
    due_date = invoice.fields.get("DueDate")
    if due_date:
        print(
            "Due Date: {} has confidence: {}".format(
                due_date.value, due_date.confidence
            )
        )
    purchase_order = invoice.fields.get("PurchaseOrder")
    if purchase_order:
        print(
            "Purchase Order: {} has confidence: {}".format(
                purchase_order.value, purchase_order.confidence
            )
        )
    billing_address = invoice.fields.get("BillingAddress")
    if billing_address:
        print(
            "Billing Address: {} has confidence: {}".format(
                billing_address.value, billing_address.confidence
            )
        )
    billing_address_recipient = invoice.fields.get("BillingAddressRecipient")
    if billing_address_recipient:
        print(
            "Billing Address Recipient: {} has confidence: {}".format(
                billing_address_recipient.value,
                billing_address_recipient.confidence,
            )
        )
    shipping_address = invoice.fields.get("ShippingAddress")
    if shipping_address:
        print(
            "Shipping Address: {} has confidence: {}".format(
                shipping_address.value, shipping_address.confidence
            )
        )
    shipping_address_recipient = invoice.fields.get("ShippingAddressRecipient")
    if shipping_address_recipient:
        print(
            "Shipping Address Recipient: {} has confidence: {}".format(
                shipping_address_recipient.value,
                shipping_address_recipient.confidence,
            )
        )
    print("Invoice items:")
    for idx, item in enumerate(invoice.fields.get("Items").value):
        print("...Item #{}".format(idx + 1))
        item_description = item.value.get("Description")
        if item_description:
            print(
                "......Description: {} has confidence: {}".format(
                    item_description.value, item_description.confidence
                )
            )
        item_quantity = item.value.get("Quantity")
        if item_quantity:
            print(
                "......Quantity: {} has confidence: {}".format(
                    item_quantity.value, item_quantity.confidence
                )
            )
        unit = item.value.get("Unit")
        if unit:
            print(
                "......Unit: {} has confidence: {}".format(
                    unit.value, unit.confidence
                )
            )
        unit_price = item.value.get("UnitPrice")
        if unit_price:
            print(
                "......Unit Price: {} has confidence: {}".format(
                    unit_price.value, unit_price.confidence
                )
            )
        product_code = item.value.get("ProductCode")
        if product_code:
            print(
                "......Product Code: {} has confidence: {}".format(
                    product_code.value, product_code.confidence
                )
            )
        item_date = item.value.get("Date")
        if item_date:
            print(
                "......Date: {} has confidence: {}".format(
                    item_date.value, item_date.confidence
                )
            )
        tax = item.value.get("Tax")
        if tax:
            print(
                "......Tax: {} has confidence: {}".format(tax.value, tax.confidence)
            )
        amount = item.value.get("Amount")
        if amount:
            print(
                "......Amount: {} has confidence: {}".format(
                    amount.value, amount.confidence
                )
            )
    subtotal = invoice.fields.get("SubTotal")
    if subtotal:
        print(
            "Subtotal: {} has confidence: {}".format(
                subtotal.value, subtotal.confidence
            )
        )
    total_tax = invoice.fields.get("TotalTax")
    if total_tax:
        print(
            "Total Tax: {} has confidence: {}".format(
                total_tax.value, total_tax.confidence
            )
        )
    previous_unpaid_balance = invoice.fields.get("PreviousUnpaidBalance")
    if previous_unpaid_balance:
        print(
            "Previous Unpaid Balance: {} has confidence: {}".format(
                previous_unpaid_balance.value, previous_unpaid_balance.confidence
            )
        )
    amount_due = invoice.fields.get("AmountDue")
    if amount_due:
        print(
            "Amount Due: {} has confidence: {}".format(
                amount_due.value, amount_due.confidence
            )
        )
    service_start_date = invoice.fields.get("ServiceStartDate")
    if service_start_date:
        print(
            "Service Start Date: {} has confidence: {}".format(
                service_start_date.value, service_start_date.confidence
            )
        )
    service_end_date = invoice.fields.get("ServiceEndDate")
    if service_end_date:
        print(
            "Service End Date: {} has confidence: {}".format(
                service_end_date.value, service_end_date.confidence
            )
        )
    service_address = invoice.fields.get("ServiceAddress")
    if service_address:
        print(
            "Service Address: {} has confidence: {}".format(
                service_address.value, service_address.confidence
            )
        )
    service_address_recipient = invoice.fields.get("ServiceAddressRecipient")
    if service_address_recipient:
        print(
            "Service Address Recipient: {} has confidence: {}".format(
                service_address_recipient.value,
                service_address_recipient.confidence,
            )
        )
    remittance_address = invoice.fields.get("RemittanceAddress")
    if remittance_address:
        print(
            "Remittance Address: {} has confidence: {}".format(
                remittance_address.value, remittance_address.confidence
            )
        )
    remittance_address_recipient = invoice.fields.get("RemittanceAddressRecipient")
    if remittance_address_recipient:
        print(
            "Remittance Address Recipient: {} has confidence: {}".format(
                remittance_address_recipient.value,
                remittance_address_recipient.confidence,
            )
        )
    print("----------------------------------------")
# Out:
# --------Recognizing invoice #1--------
# Vendor Name: CONTOSO LTD. has confidence: 0.933
# Vendor Address: AddressValue(house_number=123, po_box=None, road=456th St, city=New York, state=NY, postal_code=10001, country_region=None, street_address=123 456th St) has confidence: 0.889
# Vendor Address Recipient: Contoso Headquarters has confidence: 0.935
# Customer Name: MICROSOFT CORPORATION has confidence: 0.826
# Customer Id: CID-12345 has confidence: 0.959
# Customer Address: AddressValue(house_number=123, po_box=None, road=Other St, city=Redmond, state=WA, postal_code=98052, country_region=None, street_address=123 Other St) has confidence: 0.893
# Customer Address Recipient: Microsoft Corp has confidence: 0.933
# Invoice Id: INV-100 has confidence: 0.971
# Invoice Date: 2019-11-15 has confidence: 0.971
# Invoice Total: $110.0 has confidence: 0.958
# Due Date: 2019-12-15 has confidence: 0.971
# Purchase Order: PO-3333 has confidence: 0.956
# Billing Address: AddressValue(house_number=123, po_box=None, road=Bill St, city=Redmond, state=WA, postal_code=98052, country_region=None, street_address=123 Bill St) has confidence: 0.889
# Billing Address Recipient: Microsoft Finance has confidence: 0.934
# Shipping Address: AddressValue(house_number=123, po_box=None, road=Ship St, city=Redmond, state=WA, postal_code=98052, country_region=None, street_address=123 Ship St) has confidence: 0.889
# Shipping Address Recipient: Microsoft Delivery has confidence: 0.933
# Invoice items:
# ...Item #1
# ......Description: Consulting service has confidence: 0.899
# ......Quantity: 1.0 has confidence: 0.9
# ......Unit Price: 1.0 has confidence: 0.871
# ......Amount: $100.0 has confidence: 0.902
# Subtotal: $100.0 has confidence: 0.971
# Total Tax: $10.0 has confidence: 0.967
# Previous Unpaid Balance: $500.0 has confidence: 0.954
# Amount Due: $610.0 has confidence: 0.952
# Service Start Date: 2019-10-14 has confidence: 0.957
# Service End Date: 2019-11-14 has confidence: 0.957
# Service Address: AddressValue(house_number=123, po_box=None, road=Service St, city=Redmond, state=WA, postal_code=98052, country_region=None, street_address=123 Service St) has confidence: 0.889
# Service Address Recipient: Microsoft Services has confidence: 0.914
# Remittance Address: AddressValue(house_number=123, po_box=None, road=Remit St, city=New York, state=NY, postal_code=10001, country_region=None, street_address=123 Remit St) has confidence: 0.889
# Remittance Address Recipient: Contoso Billing has confidence: 0.934
# ----------------------------------------

# %%
invoices
# Out:
# AnalyzeResult(api_version=2022-08-31, model_id=prebuilt-invoice, content=CONTOSO LTD.
# Contoso Headquarters 123 456th St New York, NY, 10001
# INVOICE
# INVOICE: INV-100 INVOICE DATE: 11/15/2019 DUE DATE: 12/15/2019 CUSTOMER NAME: MICROSOFT CORPORATION SERVICE PERIOD: 10/14/2019 - 11/14/2019 CUSTOMER ID: CID-12345
# Microsoft Corp 123 Other St, Redmond WA, 98052
# BILL TO:
# Microsoft Finance
# 123 Bill St,
# Redmond WA, 98052
# SHIP TO:
# Microsoft Delivery
# 123 Ship St,
# Redmond WA, 98052
# SERVICE ADDRESS: Microsoft Services 123 Service St, Redmond WA, 98052
# SALESPERSON
# P.O. NUMBER
# REQUISITIONER
# SHIPPED VIA
# F.O.B. POINT
# TERMS
# PO-3333
# QUANTITY
# DESCRIPTION
# UNIT PRICE
# TOTAL
# 1
# Consulting service
# 1
# $100.00
# SUBTOTAL
# $100.00
# SALES TAX
# $10.00
# TOTAL
# $110.00
# PREVIOUS UNPAID BALANCE
# $500.00
# THANK YOU FOR YOUR BUSINESS!
# REMIT TO:
# Contoso Billing
# 123 Remit St
# New York, NY, 10001
# TOTAL DUE
# $610.00, languages=[], pages=[DocumentPage(page_number=1, angle=None, width=1700.0, height=2200.0, unit=pixel, lines=[DocumentLine(content=CONTOSO LTD., polygon=[Point(x=112.0, y=130.0), Point(x=469.0, y=129.0), Point(x=469.0, y=177.0), Point(x=112.0, y=178.0)], spans=[DocumentSpan(offset=0, length=12)]), DocumentLine(content=Contoso Headquarters, polygon=[Point(x=112.0, y=280.0), Point(x=424.0, y=282.0), Point(x=424.0, y=314.0), Point(x=112.0, y=312.0)], spans=[DocumentSpan(offset=13, length=20)]), DocumentLine(content=123 456th St, polygon=[Point(x=114.0, y=320.0), Point(x=278.0, y=320.0), Point(x=278.0, y=352.0), Point(x=114.0, y=352.0)], spans=[DocumentSpan(offset=34, length=12)]), DocumentLine(content=New York, NY, 10001, polygon=[Point(x=113.0, y=361.0), Point(x=401.0, y=360.0), Point(x=401.0, y=393.0), Point(x=113.0, y=394.0)], spans=[DocumentSpan(offset=47, length=19)]), DocumentLine(content=INVOICE, polygon=[Point(x=1409.0, y=112.0), Point(x=1603.0, y=111.0), Point(x=1603.0, y=156.0), Point(x=1409.0, y=158.0)], spans=[DocumentSpan(offset=67, length=7)]), DocumentLine(content=INVOICE: INV-100, polygon=[Point(x=1366.0, y=278.0), Point(x=1601.0, y=278.0), Point(x=1601.0, y=309.0), Point(x=1366.0, y=309.0)], spans=[DocumentSpan(offset=75, length=16)]), DocumentLine(content=INVOICE DATE: 11/15/2019, polygon=[Point(x=1241.0, y=319.0), Point(x=1599.0, y=320.0), Point(x=1599.0, y=350.0), Point(x=1241.0, y=349.0)], spans=[DocumentSpan(offset=92, length=24)]), DocumentLine(content=DUE DATE: 12/15/2019, polygon=[Point(x=1296.0, y=359.0), Point(x=1598.0, y=359.0), Point(x=1598.0, y=392.0), Point(x=1296.0, y=391.0)], spans=[DocumentSpan(offset=117, length=20)]), DocumentLine(content=CUSTOMER NAME: MICROSOFT CORPORATION, polygon=[Point(x=985.0, y=401.0), Point(x=1600.0, y=401.0), Point(x=1600.0, y=431.0), Point(x=985.0, y=431.0)], spans=[DocumentSpan(offset=138, length=36)]), DocumentLine(content=SERVICE PERIOD: 10/14/2019 - 11/14/2019, polygon=[Point(x=1029.0, y=442.0), Point(x=1600.0, y=443.0), Point(x=1600.0, y=473.0), Point(x=1029.0, y=472.0)], spans=[DocumentSpan(offset=175, length=39)]), DocumentLine(content=CUSTOMER ID: CID-12345, polygon=[Point(x=1260.0, y=484.0), Point(x=1599.0, y=484.0), Point(x=1598.0, y=513.0), Point(x=1260.0, y=512.0)], spans=[DocumentSpan(offset=215, length=22)]), DocumentLine(content=Microsoft Corp, polygon=[Point(x=113.0, y=525.0), Point(x=320.0, y=525.0), Point(x=320.0, y=559.0), Point(x=112.0, y=557.0)], spans=[DocumentSpan(offset=238, length=14)]), DocumentLine(content=123 Other St,, polygon=[Point(x=114.0, y=564.0), Point(x=296.0, y=565.0), Point(x=296.0, y=598.0), Point(x=114.0, y=597.0)], spans=[DocumentSpan(offset=253, length=13)]), DocumentLine(content=Redmond WA, 98052, polygon=[Point(x=113.0, y=605.0), Point(x=404.0, y=606.0), Point(x=404.0, y=639.0), Point(x=113.0, y=638.0)], spans=[DocumentSpan(offset=267, length=17)]), DocumentLine(content=BILL TO:, polygon=[Point(x=113.0, y=787.0), Point(x=222.0, y=788.0), Point(x=221.0, y=816.0), Point(x=113.0, y=816.0)], spans=[DocumentSpan(offset=285, length=8)]), DocumentLine(content=Microsoft Finance, polygon=[Point(x=114.0, y=830.0), Point(x=361.0, y=831.0), Point(x=361.0, y=861.0), Point(x=114.0, y=861.0)], spans=[DocumentSpan(offset=294, length=17)]), DocumentLine(content=123 Bill St,, polygon=[Point(x=117.0, y=870.0), Point(x=258.0, y=870.0), Point(x=258.0, y=903.0), Point(x=117.0, y=903.0)], spans=[DocumentSpan(offset=312, length=12)]), DocumentLine(content=Redmond WA, 98052, polygon=[Point(x=115.0, y=910.0), Point(x=406.0, y=910.0), Point(x=406.0, y=942.0), Point(x=115.0, y=942.0)], spans=[DocumentSpan(offset=325, length=17)]), DocumentLine(content=SHIP TO:, polygon=[Point(x=661.0, y=787.0), Point(x=779.0, y=788.0), Point(x=779.0, y=816.0), Point(x=661.0, y=816.0)], spans=[DocumentSpan(offset=343, length=8)]), DocumentLine(content=Microsoft Delivery, polygon=[Point(x=665.0, y=830.0), Point(x=918.0, y=831.0), Point(x=918.0, y=863.0), Point(x= ...
# 123 Bill St,
# Redmond WA, 98052, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=114.0, y=831.0), Point(x=403.0, y=829.0), Point(x=403.0, y=943.0), Point(x=115.0, y=945.0)])], spans=[DocumentSpan(offset=294, length=48)]), confidence=0.834), DocumentKeyValuePair(key=DocumentKeyValueElement(content=SHIP TO:, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=662.0, y=788.0), Point(x=780.0, y=789.0), Point(x=780.0, y=818.0), Point(x=662.0, y=817.0)])], spans=[DocumentSpan(offset=343, length=8)]), value=DocumentKeyValueElement(content=Microsoft Delivery
# 123 Ship St,
# Redmond WA, 98052, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=665.0, y=830.0), Point(x=953.0, y=831.0), Point(x=953.0, y=945.0), Point(x=665.0, y=944.0)])], spans=[DocumentSpan(offset=352, length=49)]), confidence=0.834), DocumentKeyValuePair(key=DocumentKeyValueElement(content=SERVICE ADDRESS:, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1239.0, y=787.0), Point(x=1487.0, y=788.0), Point(x=1487.0, y=818.0), Point(x=1239.0, y=817.0)])], spans=[DocumentSpan(offset=402, length=16)]), value=DocumentKeyValueElement(content=Microsoft Services 123 Service St, Redmond WA, 98052, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1239.0, y=831.0), Point(x=1530.0, y=831.0), Point(x=1530.0, y=945.0), Point(x=1239.0, y=945.0)])], spans=[DocumentSpan(offset=419, length=52)]), confidence=0.834), DocumentKeyValuePair(key=DocumentKeyValueElement(content=P.O. NUMBER, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=420.0, y=1006.0), Point(x=598.0, y=1007.0), Point(x=598.0, y=1036.0), Point(x=420.0, y=1035.0)])], spans=[DocumentSpan(offset=484, length=11)]), value=DocumentKeyValueElement(content=PO-3333, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=378.0, y=1063.0), Point(x=491.0, y=1064.0), Point(x=491.0, y=1090.0), Point(x=378.0, y=1091.0)])], spans=[DocumentSpan(offset=541, length=7)]), confidence=0.908), DocumentKeyValuePair(key=DocumentKeyValueElement(content=QUANTITY, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=161.0, y=1161.0), Point(x=299.0, y=1160.0), Point(x=299.0, y=1187.0), Point(x=161.0, y=1189.0)])], spans=[DocumentSpan(offset=549, length=8)]), value=DocumentKeyValueElement(content=1, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=116.0, y=1219.0), Point(x=130.0, y=1218.0), Point(x=131.0, y=1243.0), Point(x=117.0, y=1244.0)])], spans=[DocumentSpan(offset=587, length=1)]), confidence=0.924), DocumentKeyValuePair(key=DocumentKeyValueElement(content=UNIT PRICE, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1179.0, y=1159.0), Point(x=1326.0, y=1160.0), Point(x=1326.0, y=1188.0), Point(x=1179.0, y=1187.0)])], spans=[DocumentSpan(offset=570, length=10)]), value=DocumentKeyValueElement(content=1, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1328.0, y=1220.0), Point(x=1344.0, y=1219.0), Point(x=1345.0, y=1244.0), Point(x=1329.0, y=1245.0)])], spans=[DocumentSpan(offset=608, length=1)]), confidence=0.526), DocumentKeyValuePair(key=DocumentKeyValueElement(content=SUBTOTAL, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1203.0, y=1331.0), Point(x=1344.0, y=1330.0), Point(x=1344.0, y=1358.0), Point(x=1204.0, y=1358.0)])], spans=[DocumentSpan(offset=618, length=8)]), value=DocumentKeyValueElement(content=$100.00, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1471.0, y=1324.0), Point(x=1583.0, y=1324.0), Point(x=1583.0, y=1355.0), Point(x=1471.0, y=1356.0)])], spans=[DocumentSpan(offset=627, length=7)]), confidence=0.927), DocumentKeyValuePair(key=DocumentKeyValueElement(content=SALES TAX, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1202.0, y=1390.0), Point(x=1341.0, y=1390.0), Point(x=1341.0, y=1418.0), Point(x=1202.0, y=1418.0)])], spans=[DocumentSpan(offset=635, length=9)]), value=DocumentKeyValueElement(content=$10.00, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1489.0, y=1383.0), Point(x=1583.0, y=1380.0), Point(x=1584.0, y=1414.0), Point(x=1489.0, y=1415.0)])], spans=[DocumentSpan(offset=645, length=6)]), confidence=0.909), DocumentKeyValuePair(key=DocumentKeyValueElement(content=TOTAL, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1258.0, y=1449.0), Point(x=1346.0, y=1450.0), Point(x=1345.0, y=1477.0), Point(x=1258.0, y=1477.0)])], spans=[DocumentSpan(offset=652, length=5)]), value=DocumentKeyValueElement(content=$110.00, bounding_regions=[BoundingRegion(page_number=1, poly ...
# 123 Remit St
# New York, NY, 10001, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=113.0, y=1863.0), Point(x=398.0, y=1863.0), Point(x=398.0, y=1975.0), Point(x=113.0, y=1975.0)])], spans=[DocumentSpan(offset=737, length=48)]), confidence=0.827)], styles=[], documents=[AnalyzedDocument(doc_type=invoice, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.0, y=0.0), Point(x=1700.0, y=0.0), Point(x=1700.0, y=2200.0), Point(x=0.0, y=2200.0)])], spans=[DocumentSpan(offset=0, length=803)], fields={'AmountDue': DocumentField(value_type=currency, value=CurrencyValue(amount=610.0, symbol=$), content=$610.00, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1471.0, y=1562.0), Point(x=1582.0, y=1563.0), Point(x=1582.0, y=1593.0), Point(x=1471.0, y=1593.0)])], spans=[DocumentSpan(offset=796, length=7)], confidence=0.952), 'BillingAddress': DocumentField(value_type=address, value=AddressValue(house_number=123, po_box=None, road=Bill St, city=Redmond, state=WA, postal_code=98052, country_region=None, street_address=123 Bill St), content=123 Bill St,
# Redmond WA, 98052, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=116.0, y=871.0), Point(x=403.0, y=869.0), Point(x=403.0, y=943.0), Point(x=116.0, y=945.0)])], spans=[DocumentSpan(offset=312, length=30)], confidence=0.889), 'BillingAddressRecipient': DocumentField(value_type=string, value='Microsoft Finance', content=Microsoft Finance, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=114.0, y=829.0), Point(x=357.0, y=832.0), Point(x=357.0, y=865.0), Point(x=114.0, y=862.0)])], spans=[DocumentSpan(offset=294, length=17)], confidence=0.934), 'CustomerAddress': DocumentField(value_type=address, value=AddressValue(house_number=123, po_box=None, road=Other St, city=Redmond, state=WA, postal_code=98052, country_region=None, street_address=123 Other St), content=123 Other St, Redmond WA, 98052, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=114.0, y=564.0), Point(x=403.0, y=565.0), Point(x=403.0, y=640.0), Point(x=114.0, y=639.0)])], spans=[DocumentSpan(offset=253, length=31)], confidence=0.893), 'CustomerAddressRecipient': DocumentField(value_type=string, value='Microsoft Corp', content=Microsoft Corp, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=113.0, y=522.0), Point(x=317.0, y=526.0), Point(x=316.0, y=560.0), Point(x=112.0, y=556.0)])], spans=[DocumentSpan(offset=238, length=14)], confidence=0.933), 'CustomerId': DocumentField(value_type=string, value='CID-12345', content=CID-12345, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1461.0, y=484.0), Point(x=1597.0, y=484.0), Point(x=1597.0, y=514.0), Point(x=1461.0, y=514.0)])], spans=[DocumentSpan(offset=228, length=9)], confidence=0.959), 'CustomerName': DocumentField(value_type=string, value='MICROSOFT CORPORATION', content=MICROSOFT CORPORATION, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1241.0, y=401.0), Point(x=1592.0, y=401.0), Point(x=1592.0, y=432.0), Point(x=1241.0, y=432.0)])], spans=[DocumentSpan(offset=153, length=21)], confidence=0.826), 'DueDate': DocumentField(value_type=date, value=datetime.date(2019, 12, 15), content=12/15/2019, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1443.0, y=361.0), Point(x=1597.0, y=360.0), Point(x=1597.0, y=393.0), Point(x=1443.0, y=390.0)])], spans=[DocumentSpan(offset=127, length=10)], confidence=0.971), 'InvoiceDate': DocumentField(value_type=date, value=datetime.date(2019, 11, 15), content=11/15/2019, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1442.0, y=320.0), Point(x=1597.0, y=320.0), Point(x=1597.0, y=351.0), Point(x=1442.0, y=351.0)])], spans=[DocumentSpan(offset=106, length=10)], confidence=0.971), 'InvoiceId': DocumentField(value_type=string, value='INV-100', content=INV-100, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1493.0, y=280.0), Point(x=1598.0, y=278.0), Point(x=1597.0, y=310.0), Point(x=1492.0, y=308.0)])], spans=[DocumentSpan(offset=84, length=7)], confidence=0.971), 'InvoiceTotal': DocumentField(value_type=currency, value=CurrencyValue(amount=110.0, symbol=$), content=$110.00, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1471.0, y=1442.0), Point(x=1582.0, y=1443.0), Point(x=1582.0, y=1473.0), Point(x=1471.0, y=1474.0)])], spans=[DocumentSpan(offset=658, length=7)], confidence=0.958), 'Items': DocumentField(value_type=list, value=[DocumentField(value_type=dictionary, value={'Amount': DocumentField(value_type=currency, value=CurrencyValue(amount=100.0, symbol=$), content=$100.00, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1472.0, y=1216.0), Point(x=1583.0, y=1215.0), Point(x=1582.0, y=1247.0), Point(x=1473.0, y=1249.0)])], spans=[DocumentSpan(offset=610, length=7)], confidence=0.902), 'Description': DocumentField(value_type=string, value='Consulting service', content=Consulting service, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=375.0, y=1216.0), Point(x=622.0, y=1218.0), Point(x=622. ...
# Consulting service
# 1
# $100.00, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=116.0, y=1218.0), Point(x=1583.0, y=1198.0), Point(x=1583.0, y=1247.0), Point(x=117.0, y=1267.0)])], spans=[DocumentSpan(offset=587, length=30)], confidence=0.902)], content=None, bounding_regions=[], spans=[], confidence=None), 'PreviousUnpaidBalance': DocumentField(value_type=currency, value=CurrencyValue(amount=500.0, symbol=$), content=$500.00, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1473.0, y=1501.0), Point(x=1582.0, y=1500.0), Point(x=1582.0, y=1535.0), Point(x=1472.0, y=1534.0)])], spans=[DocumentSpan(offset=690, length=7)], confidence=0.954), 'PurchaseOrder': DocumentField(value_type=string, value='PO-3333', content=PO-3333, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=378.0, y=1063.0), Point(x=491.0, y=1064.0), Point(x=491.0, y=1090.0), Point(x=378.0, y=1091.0)])], spans=[DocumentSpan(offset=541, length=7)], confidence=0.956), 'RemittanceAddress': DocumentField(value_type=address, value=AddressValue(house_number=123, po_box=None, road=Remit St, city=New York, state=NY, postal_code=10001, country_region=None, street_address=123 Remit St), content=123 Remit St
# New York, NY, 10001, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=113.0, y=1902.0), Point(x=398.0, y=1902.0), Point(x=398.0, y=1975.0), Point(x=113.0, y=1975.0)])], spans=[DocumentSpan(offset=753, length=32)], confidence=0.889), 'RemittanceAddressRecipient': DocumentField(value_type=string, value='Contoso Billing', content=Contoso Billing, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=115.0, y=1860.0), Point(x=318.0, y=1864.0), Point(x=317.0, y=1897.0), Point(x=114.0, y=1893.0)])], spans=[DocumentSpan(offset=737, length=15)], confidence=0.934), 'ServiceAddress': DocumentField(value_type=address, value=AddressValue(house_number=123, po_box=None, road=Service St, city=Redmond, state=WA, postal_code=98052, country_region=None, street_address=123 Service St), content=123 Service St, Redmond WA, 98052, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1239.0, y=871.0), Point(x=1530.0, y=871.0), Point(x=1530.0, y=945.0), Point(x=1239.0, y=945.0)])], spans=[DocumentSpan(offset=438, length=33)], confidence=0.889), 'ServiceAddressRecipient': DocumentField(value_type=string, value='Microsoft Services', content=Microsoft Services, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1239.0, y=830.0), Point(x=1490.0, y=832.0), Point(x=1490.0, y=863.0), Point(x=1239.0, y=861.0)])], spans=[DocumentSpan(offset=419, length=18)], confidence=0.914), 'ServiceEndDate': DocumentField(value_type=date, value=datetime.date(2019, 11, 14), content=11/14/2019, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1443.0, y=443.0), Point(x=1597.0, y=443.0), Point(x=1597.0, y=474.0), Point(x=1443.0, y=474.0)])], spans=[DocumentSpan(offset=204, length=10)], confidence=0.957), 'ServiceStartDate': DocumentField(value_type=date, value=datetime.date(2019, 10, 14), content=10/14/2019, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1260.0, y=443.0), Point(x=1413.0, y=443.0), Point(x=1413.0, y=474.0), Point(x=1260.0, y=473.0)])], spans=[DocumentSpan(offset=191, length=10)], confidence=0.957), 'ShippingAddress': DocumentField(value_type=address, value=AddressValue(house_number=123, po_box=None, road=Ship St, city=Redmond, state=WA, postal_code=98052, country_region=None, street_address=123 Ship St), content=123 Ship St,
# Redmond WA, 98052, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=665.0, y=871.0), Point(x=953.0, y=871.0), Point(x=953.0, y=944.0), Point(x=665.0, y=944.0)])], spans=[DocumentSpan(offset=371, length=30)], confidence=0.889), 'ShippingAddressRecipient': DocumentField(value_type=string, value='Microsoft Delivery', content=Microsoft Delivery, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=666.0, y=829.0), Point(x=918.0, y=831.0), Point(x=918.0, y=864.0), Point(x=666.0, y=862.0)])], spans=[DocumentSpan(offset=352, length=18)], confidence=0.933), 'SubTotal': DocumentField(value_type=currency, value=CurrencyValue(amount=100.0, symbol=$), content=$100.00, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1471.0, y=1324.0), Point(x=1583.0, y=1324.0), Point(x=1583.0, y=1355.0), Point(x=1471.0, y=1356.0)])], spans=[DocumentSpan(offset=627, length=7)], confidence=0.971), 'TotalTax': DocumentField(value_type=currency, value=CurrencyValue(amount=10.0, symbol=$), content=$10.00, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1489.0, y=1383.0), Point(x=1583.0, y=1380.0), Point(x=1584.0, y=1414.0), Point(x=1489.0, y=1415.0)])], spans=[DocumentSpan(offset=645, length=6)], confidence=0.967), 'VendorAddress': DocumentField(value_type=address, value=AddressValue(house_number=123, po_box=None, road=456th St, city=New York, state=NY, postal_code=10001, country_region=None, street_address=123 456th St), content=123 456th St New York, NY, 10001, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=113.0, y=320.0), Point(x=400.0, y=320.0), Point(x=400.0, y=395.0), Point(x=113.0, y=395.0)])], spans=[DocumentSpan(offset=34, length=32)], confidence=0.889), 'VendorAddressRecipient': DocumentField(value_type=string, value='Contoso Headquarters', content=Contoso Headquarters, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=113.0, y=278.0), Point(x=424.0, y=282.0), Point(x=424.0, y=317.0), Point(x=113.0, y=312.0)])], spans=[DocumentSpan(offset=13, length=20)], confidence=0.935), 'VendorName': DocumentField(value_type=string, value='CONTOSO LTD.', content=CONTOSO LTD., bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=112.0, y=130.0), Point(x=468.0, y=129.0), Point(x=468.0, y=178.0), Point(x=112.0, y=179.0)])], spans=[DocumentSpan(offset=0, length=12)], confidence=0.933)}, confidence=1.0)])

# %%
import pandas as pd

# Your existing code here...

# Initialize empty lists to store table data
table_data = []
table_info = []

for table_idx, table in enumerate(result.tables):
    table_info.append("Table # {} has {} rows and {} columns".format(
        table_idx, table.row_count, table.column_count
    ))
    # Initialize an empty list for each table row
    table_rows = []
    for cell in table.cells:
        # Append the cell content to the row list
        table_rows.append(cell.content.decode("utf-8"))
    # Append the row list to the table data list
    table_data.append(table_rows)

# Convert the table data to a DataFrame
df = pd.DataFrame(table_data)

# Print table information
for info in table_info:
    print(info)

# Print the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17736\253128162.py in <module>
#       7 table_info = []
#       8
# ----> 9 for table_idx, table in enumerate(result.tables):
#      10     table_info.append("Table # {} has {} rows and {} columns".format(
#      11         table_idx, table.row_count, table.column_count
#
# NameError: name 'result' is not defined
